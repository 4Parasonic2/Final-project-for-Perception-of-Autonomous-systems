# %% [markdown]
# # Final Project Sequence 2
#
# This sequence is about detecting and tracking pedestrians, cyclists and cars. In the sequence is an occlusion which the code needs to try and track when the objects goes behind that. This should be obtained based on YOLO object detection and the kalman filter we was teached about in lecture 7 about state estimation. This sequence has ground truth which makes it possible to validate performance of the system

# %% [markdown]
# # Step 1
# Start by looping through the images to get an understanding of what we are working with and the obstacles in the sequence, to gain an idea of how to solve the execise.

# %%
#Imports needed for the application
import cv2
import glob
import os
from ultralytics import YOLO 
import numpy as np
import math
import time
from scipy.optimize import linear_sum_assignment
import pandas as pd
from tqdm import tqdm

# Change this path to the one that works for you
img_folder = "34759_final_project_rect/seq_02/image_02/data"

images = sorted(glob.glob(os.path.join(img_folder, "*.png")))
# Check to see if images are found
if not images:
    raise FileNotFoundError("No images found. Check your folder path.")

# Loop through images in the sequence
for i, img_path in enumerate(images):
    frame = cv2.imread(img_path)
    if frame is None:
        print("Failed to load:", img_path)
        continue

    cv2.imshow("Left Camera Sequence", frame) # The left images are the ground truth
    key = cv2.waitKey(30)
    if key == 27:  # ESC
        break

cv2.destroyAllWindows()

# %% [markdown]
# # Step 2
# Look at the labels.txt file to get an idea of what the there is inside of it and what to use

# %%
cols = ["frame","track_id","type","truncated","occluded","alpha",
        "left","top","right","bottom",
        "height","width","length",
        "x","y","z","rot_y"]

# Use pandas to read the txt file
labels = pd.read_csv("C:/Users/senik/Documents/2. Semester/Perception for Autonomous Systems/Final project/34759_final_project_rect/seq_02/labels.txt", sep=" ", names=cols)

# %%
#Pick an image in the sequence to see the ground truth data based on the labels.txt 
frame_id = 0
frame_dets = labels[labels["frame"] == frame_id]
for _, row in frame_dets.iterrows():
    print(f'Type: {row["type"]}       X: {row["x"]}        Y: {row["y"]}          Z: {row["z"]}')
# Out:
# Type: Car       X: 19.26026        Y: 1.775559          Z: 24.51019
# Type: Car       X: 16.289924        Y: 1.602928          Z: 23.743018
# Type: Car       X: 13.738582        Y: 1.691811          Z: 24.225602
# Type: Car       X: 0.723855        Y: 1.091199          Z: 36.838675
# Type: Cyclist       X: -2.85975        Y: 1.524929          Z: 8.816594
# Type: Pedestrian       X: 2.383949        Y: 1.44522          Z: 10.654481
# Type: Pedestrian       X: 3.220755        Y: 1.423812          Z: 11.111037
# Type: Pedestrian       X: -2.918292        Y: 1.420417          Z: 14.233725
# Type: Pedestrian       X: -8.353782        Y: 1.274824          Z: 18.866601
# Type: Pedestrian       X: -7.643764        Y: 1.248348          Z: 19.522313
# Type: Pedestrian       X: -11.048167        Y: 1.115481          Z: 20.605951
# Type: Pedestrian       X: -10.299781        Y: 1.083621          Z: 20.859352
# Type: Pedestrian       X: -9.571061        Y: 1.089269          Z: 21.128756

# %% [markdown]
# # Helper functions for yolo model without kalman filter

# %%
# This function does the finding of a cyclist based on a person sitting on the bike so the overlap between the bounding box of a person and the bike
def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0]); yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2]); yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)
    boxAArea = max(1, (boxA[2] - boxA[0])) * max(1, (boxA[3] - boxA[1]))
    boxBArea = max(1, (boxB[2] - boxB[0])) * max(1, (boxB[3] - boxB[1]))
    return interArea / float(boxAArea + boxBArea - interArea + 1e-6)

# %% [markdown]
# # Step 3
# Find out how good the yolo model is based on the grounth truth without the kalman filter for tracktion

# %%
# Load YOLO
model = YOLO("yolo11l.pt")
allowed_classes = {"person", "car", "bicycle"}

# Metrics for evaluation of the models performance
TP, FP, FN = 0, 0, 0 # TP = True positive, FP = False positive, FN = False negative

for frame_id, frame_path in enumerate(images):

    # Read frame
    frame = cv2.imread(frame_path)
    if frame is None:
        continue

    frame_for_yolo = frame.copy() # clean input to YOLO
    frame_disp = frame.copy() # used only for drawing


    # Ground truth
    frame_gt = labels[labels["frame"] == frame_id]
    gt_boxes, gt_labels = [], []

    for _, row in frame_gt.iterrows():
        cls = row["type"].lower()
        if cls in {"car", "pedestrian", "cyclist"}:
            box = [row["left"], row["top"], row["right"], row["bottom"]]
            gt_boxes.append(box)
            gt_labels.append(cls)

            # Draw Ground truth bonding boxes
            cv2.rectangle(frame_disp, 
                          (int(box[0]), int(box[1])), 
                          (int(box[2]), int(box[3])), 
                          (0, 255, 0), 2)
            
            # Draw the label above the bounding box
            cv2.putText(frame_disp, f"GT {cls}", 
                        (int(box[0]), int(box[1]) - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                        (0, 255, 0), 1)


    # Start yolo detection on the current frame
    results = model(frame_for_yolo)

    raw = []
    for r in results:
        boxes = r.boxes.xyxy.cpu().numpy() # Extracts the boundingbox coordinates into a numoy array
        confs = r.boxes.conf.cpu().numpy() # Extracsts the confidence of the detections
        clss = r.boxes.cls.cpu().numpy() # Extracts the class label for the detections

        for box, conf, cls in zip(boxes, confs, clss):
            label = model.names[int(cls)]
            if label in allowed_classes and conf >= 0.5: # Remove objects detected under a confidence of 50%
                raw.append((box, conf, label))


    # Merge cyclists which is a person on a bike
    used = set()
    preds = []

    for i, (box1, conf1, label1) in enumerate(raw):
        if label1 != "person":
            continue

        for j, (box2, conf2, label2) in enumerate(raw):
            if label2 != "bicycle" or j in used:
                continue

            if iou(box1, box2) > 0.2: #Threshold for when it is a cyclist
                x1 = min(int(box1[0]), int(box2[0]))
                y1 = min(int(box1[1]), int(box2[1]))
                x2 = max(int(box1[2]), int(box2[2]))
                y2 = max(int(box1[3]), int(box2[3]))
                # Add cyclists to the detections
                preds.append(([x1, y1, x2, y2], (conf1 + conf2)/2, "cyclist"))
                used.add(i)
                used.add(j)


    # Add the detections of cars and pedestrians
    for k, (box, conf, label) in enumerate(raw):
        if k in used:
            continue

        if label == "car":
            # Add cars to the detections
            preds.append((list(map(int, box)), conf, "car"))
        elif label == "person":
            # Add pedestrians to the detections
            preds.append((list(map(int, box)), conf, "pedestrian"))


    # Draw a bounding box around the detections
    for box, conf, cls in preds:
        x1, y1, x2, y2 = map(int, box)
        color = (0, 255, 255) if cls == "cyclist" else (255, 0, 0)

        cv2.rectangle(frame_disp, (x1, y1), (x2, y2), color, 2)
        cv2.putText(frame_disp, f"{cls} {conf:.2f}", 
                    (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                    color, 1)


    # Make evaluation of the model
    matched_gt = set()

    for box, conf, cls in preds:
        best_iou = 0
        best_idx = None

        for gi, gt_box in enumerate(gt_boxes):
            i = iou(box, gt_box)
            if i > best_iou:
                best_iou = i
                best_idx = gi

        if best_iou >= 0.5: #Threshold for overlapping between ground truth and yolo detections to find out if the detection is correct
            TP += 1
            matched_gt.add(best_idx)

            # Draw TP marker
            cv2.putText(frame_disp, "TP", 
                        (int(box[0]), int(box[1]) - 25),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                        (255, 0, 255), 1)
        else:
            FP += 1

    FN += len(gt_boxes) - len(matched_gt)


    # Show the frames in the sequence as a video
    cv2.imshow("Detections + Ground Truth", frame_disp)
    if cv2.waitKey(30) == 27:
        break


cv2.destroyAllWindows()


# Print evaluations for the model
precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1_score = 2 * (precision * recall) / (precision + recall) if precision + recall > 0 else 0.0
mAP = TP/(TP+FP+FN)

print("-" * 30)
print(f"TOTAL FRAMES: {frame_id + 1}")
print(f"TP={TP}, FP={FP}, FN={FN}")
print("-" * 30)
print(f"Precision = {precision:.3f}")
print(f"Recall    = {recall:.3f}")
print(f"F1-Score  = {f1_score:.3f}")
print(f"mAP  = {mAP:.3f}")
print("-" * 30)
# Out:
# 0: 224x640 8 persons, 2 bicycles, 3 cars, 1 motorcycle, 425.4ms
# Speed: 18.6ms preprocess, 425.4ms inference, 16.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 2 bicycles, 3 cars, 1 motorcycle, 398.6ms
# Speed: 1.5ms preprocess, 398.6ms inference, 3.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 2 bicycles, 3 cars, 1 motorcycle, 1 backpack, 390.9ms
# Speed: 1.4ms preprocess, 390.9ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 2 bicycles, 4 cars, 1 motorcycle, 400.3ms
# Speed: 1.8ms preprocess, 400.3ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 2 bicycles, 3 cars, 1 motorcycle, 349.4ms
# Speed: 1.3ms preprocess, 349.4ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 2 bicycles, 5 cars, 1 motorcycle, 337.4ms
# Speed: 1.4ms preprocess, 337.4ms inference, 4.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 2 bicycles, 3 cars, 1 motorcycle, 1 handbag, 336.5ms
# Speed: 1.5ms preprocess, 336.5ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 2 bicycles, 4 cars, 1 motorcycle, 1 handbag, 332.8ms
# Speed: 1.3ms preprocess, 332.8ms inference, 4.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 2 bicycles, 3 cars, 384.7ms
# Speed: 1.3ms preprocess, 384.7ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 5 cars, 1 handbag, 388.0ms
# Speed: 1.4ms preprocess, 388.0ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 4 cars, 2 motorcycles, 1 handbag, 387.8ms
# Speed: 1.4ms preprocess, 387.8ms inference, 3.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 1 bicycle, 4 cars, 2 motorcycles, 1 handbag, 320.8ms
# Speed: 1.7ms preprocess, 320.8ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 5 cars, 1 motorcycle, 312.5ms
# Speed: 1.3ms preprocess, 312.5ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 4 cars, 1 motorcycle, 386.5ms
# Speed: 1.4ms preprocess, 386.5ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 1 bicycle, 4 cars, 1 motorcycle, 1 bench, 404.6ms
# Speed: 1.3ms preprocess, 404.6ms inference, 4.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 5 cars, 1 motorcycle, 1 bench, 399.2ms
# Speed: 1.3ms preprocess, 399.2ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 bench, 360.3ms
# Speed: 2.9ms preprocess, 360.3ms inference, 4.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 4 cars, 1 motorcycle, 1 handbag, 334.2ms
# Speed: 1.5ms preprocess, 334.2ms inference, 2.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 handbag, 322.9ms
# Speed: 1.4ms preprocess, 322.9ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 5 cars, 1 motorcycle, 1 handbag, 308.3ms
# Speed: 1.4ms preprocess, 308.3ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 5 cars, 1 motorcycle, 1 handbag, 320.9ms
# Speed: 1.3ms preprocess, 320.9ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 5 cars, 1 motorcycle, 1 handbag, 327.1ms
# Speed: 1.9ms preprocess, 327.1ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 4 cars, 1 motorcycle, 337.7ms
# Speed: 1.5ms preprocess, 337.7ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 4 cars, 1 motorcycle, 328.2ms
# Speed: 1.6ms preprocess, 328.2ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 4 cars, 1 motorcycle, 321.1ms
# Speed: 1.5ms preprocess, 321.1ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 4 cars, 1 motorcycle, 1 handbag, 427.8ms
# Speed: 1.5ms preprocess, 427.8ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 4 cars, 1 motorcycle, 1 handbag, 321.7ms
# Speed: 1.3ms preprocess, 321.7ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 handbag, 313.3ms
# Speed: 1.4ms preprocess, 313.3ms inference, 5.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 4 cars, 1 motorcycle, 1 handbag, 329.4ms
# Speed: 2.5ms preprocess, 329.4ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 handbag, 313.3ms
# Speed: 1.3ms preprocess, 313.3ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 bench, 1 handbag, 311.1ms
# Speed: 1.8ms preprocess, 311.1ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 2 cars, 1 motorcycle, 326.6ms
# Speed: 1.3ms preprocess, 326.6ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 2 cars, 1 motorcycle, 322.6ms
# Speed: 1.3ms preprocess, 322.6ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 3 cars, 1 motorcycle, 312.5ms
# Speed: 1.3ms preprocess, 312.5ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 2 cars, 1 motorcycle, 400.1ms
# Speed: 1.6ms preprocess, 400.1ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 2 cars, 1 motorcycle, 1 bench, 418.5ms
# Speed: 1.7ms preprocess, 418.5ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 2 cars, 1 motorcycle, 1 bench, 320.6ms
# Speed: 1.3ms preprocess, 320.6ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 bench, 305.9ms
# Speed: 1.4ms preprocess, 305.9ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 2 cars, 1 motorcycle, 1 bench, 303.1ms
# Speed: 1.3ms preprocess, 303.1ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 2 cars, 1 motorcycle, 1 bench, 309.4ms
# Speed: 1.4ms preprocess, 309.4ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 3 cars, 1 motorcycle, 307.1ms
# Speed: 1.5ms preprocess, 307.1ms inference, 3.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 4 cars, 1 motorcycle, 304.0ms
# Speed: 1.3ms preprocess, 304.0ms inference, 2.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 1 bicycle, 3 cars, 1 motorcycle, 308.4ms
# Speed: 1.3ms preprocess, 308.4ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 4 cars, 1 motorcycle, 310.0ms
# Speed: 1.3ms preprocess, 310.0ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 3 cars, 1 motorcycle, 309.1ms
# Speed: 1.4ms preprocess, 309.1ms inference, 2.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 3 cars, 1 motorcycle, 304.3ms
# Speed: 1.6ms preprocess, 304.3ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 4 cars, 1 motorcycle, 312.9ms
# Speed: 1.4ms preprocess, 312.9ms inference, 2.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 3 cars, 1 motorcycle, 318.6ms
# Speed: 1.4ms preprocess, 318.6ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 1 bicycle, 3 cars, 1 motorcycle, 328.6ms
# Speed: 1.3ms preprocess, 328.6ms inference, 2.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 1 bicycle, 4 cars, 1 motorcycle, 316.9ms
# Speed: 1.5ms preprocess, 316.9ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 1 bicycle, 3 cars, 1 motorcycle, 311.1ms
# Speed: 1.4ms preprocess, 311.1ms inference, 2.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 4 cars, 1 motorcycle, 348.6ms
# Speed: 1.5ms preprocess, 348.6ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 4 cars, 1 motorcycle, 302.1ms
# Speed: 1.4ms preprocess, 302.1ms inference, 2.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 1 bicycle, 5 cars, 1 motorcycle, 302.8ms
# Speed: 1.6ms preprocess, 302.8ms inference, 2.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 5 cars, 1 motorcycle, 303.6ms
# Speed: 1.4ms preprocess, 303.6ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 4 cars, 1 motorcycle, 2 handbags, 306.0ms
# Speed: 1.4ms preprocess, 306.0ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 5 cars, 1 motorcycle, 2 handbags, 305.6ms
# Speed: 1.3ms preprocess, 305.6ms inference, 3.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 4 cars, 1 motorcycle, 1 handbag, 302.6ms
# Speed: 1.5ms preprocess, 302.6ms inference, 4.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 5 cars, 1 motorcycle, 2 handbags, 304.8ms
# Speed: 1.5ms preprocess, 304.8ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 5 cars, 1 motorcycle, 1 handbag, 303.8ms
# Speed: 1.4ms preprocess, 303.8ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 4 cars, 1 motorcycle, 1 handbag, 310.9ms
# Speed: 1.3ms preprocess, 310.9ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 3 cars, 2 motorcycles, 1 handbag, 298.9ms
# Speed: 1.4ms preprocess, 298.9ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 1 bicycle, 2 cars, 3 motorcycles, 301.1ms
# Speed: 1.3ms preprocess, 301.1ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 4 cars, 1 motorcycle, 1 handbag, 303.4ms
# Speed: 1.3ms preprocess, 303.4ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 13 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 handbag, 301.6ms
# Speed: 1.3ms preprocess, 301.6ms inference, 3.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 1 bicycle, 2 cars, 1 motorcycle, 1 handbag, 302.0ms
# Speed: 1.3ms preprocess, 302.0ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 14 persons, 1 bicycle, 4 cars, 1 motorcycle, 1 bench, 1 handbag, 329.1ms
# Speed: 1.3ms preprocess, 329.1ms inference, 4.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 1 bicycle, 2 cars, 1 motorcycle, 1 bench, 1 handbag, 308.4ms
# Speed: 1.5ms preprocess, 308.4ms inference, 4.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 bench, 1 handbag, 321.6ms
# Speed: 1.3ms preprocess, 321.6ms inference, 4.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 bench, 1 handbag, 352.4ms
# Speed: 1.4ms preprocess, 352.4ms inference, 4.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 3 cars, 1 motorcycle, 311.1ms
# Speed: 1.5ms preprocess, 311.1ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 13 persons, 3 cars, 1 motorcycle, 1 handbag, 327.9ms
# Speed: 1.3ms preprocess, 327.9ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 13 persons, 1 bicycle, 3 cars, 1 motorcycle, 326.3ms
# Speed: 1.6ms preprocess, 326.3ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 3 cars, 1 motorcycle, 317.9ms
# Speed: 1.3ms preprocess, 317.9ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 1 bicycle, 3 cars, 1 motorcycle, 315.1ms
# Speed: 1.4ms preprocess, 315.1ms inference, 5.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 13 persons, 1 bicycle, 3 cars, 1 motorcycle, 326.6ms
# Speed: 12.5ms preprocess, 326.6ms inference, 4.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 1 bicycle, 3 cars, 1 motorcycle, 343.8ms
# Speed: 1.3ms preprocess, 343.8ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 3 cars, 1 motorcycle, 306.6ms
# Speed: 1.4ms preprocess, 306.6ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 3 cars, 1 motorcycle, 315.5ms
# Speed: 1.6ms preprocess, 315.5ms inference, 8.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 3 cars, 1 motorcycle, 302.6ms
# Speed: 1.7ms preprocess, 302.6ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 13 persons, 1 bicycle, 3 cars, 1 motorcycle, 468.5ms
# Speed: 1.8ms preprocess, 468.5ms inference, 5.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 1 bicycle, 3 cars, 1 motorcycle, 367.8ms
# Speed: 1.6ms preprocess, 367.8ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 3 cars, 1 motorcycle, 379.5ms
# Speed: 1.3ms preprocess, 379.5ms inference, 4.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 4 cars, 1 motorcycle, 399.3ms
# Speed: 1.8ms preprocess, 399.3ms inference, 4.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 4 cars, 1 motorcycle, 1 vase, 478.2ms
# Speed: 2.4ms preprocess, 478.2ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 4 cars, 1 motorcycle, 1 bench, 439.9ms
# Speed: 3.6ms preprocess, 439.9ms inference, 4.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 1 bicycle, 4 cars, 1 motorcycle, 404.5ms
# Speed: 1.5ms preprocess, 404.5ms inference, 4.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 4 cars, 1 motorcycle, 354.0ms
# Speed: 1.9ms preprocess, 354.0ms inference, 5.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 4 cars, 1 motorcycle, 450.9ms
# Speed: 1.7ms preprocess, 450.9ms inference, 4.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 3 cars, 1 motorcycle, 396.6ms
# Speed: 2.2ms preprocess, 396.6ms inference, 5.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 3 cars, 1 motorcycle, 453.5ms
# Speed: 3.1ms preprocess, 453.5ms inference, 4.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 3 cars, 1 motorcycle, 453.4ms
# Speed: 3.4ms preprocess, 453.4ms inference, 4.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 3 cars, 1 motorcycle, 475.8ms
# Speed: 1.8ms preprocess, 475.8ms inference, 4.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 3 cars, 1 motorcycle, 401.2ms
# Speed: 1.7ms preprocess, 401.2ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 3 cars, 1 motorcycle, 375.9ms
# Speed: 1.6ms preprocess, 375.9ms inference, 4.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 3 cars, 1 motorcycle, 384.2ms
# Speed: 1.5ms preprocess, 384.2ms inference, 4.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 3 cars, 1 motorcycle, 372.2ms
# Speed: 2.3ms preprocess, 372.2ms inference, 5.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 3 cars, 1 motorcycle, 353.4ms
# Speed: 1.5ms preprocess, 353.4ms inference, 5.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 3 cars, 1 motorcycle, 363.8ms
# Speed: 1.8ms preprocess, 363.8ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 3 cars, 1 motorcycle, 350.4ms
# Speed: 2.1ms preprocess, 350.4ms inference, 4.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 3 cars, 1 motorcycle, 391.9ms
# Speed: 1.7ms preprocess, 391.9ms inference, 4.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 3 cars, 1 motorcycle, 484.4ms
# Speed: 1.7ms preprocess, 484.4ms inference, 4.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 3 cars, 1 motorcycle, 493.4ms
# Speed: 1.3ms preprocess, 493.4ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 3 cars, 1 motorcycle, 397.5ms
# Speed: 1.7ms preprocess, 397.5ms inference, 4.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 1 bicycle, 4 cars, 1 motorcycle, 384.7ms
# Speed: 1.8ms preprocess, 384.7ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 4 cars, 1 motorcycle, 356.5ms
# Speed: 1.6ms preprocess, 356.5ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 1 bicycle, 4 cars, 1 motorcycle, 1 bench, 364.5ms
# Speed: 1.6ms preprocess, 364.5ms inference, 3.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 bench, 370.3ms
# Speed: 2.1ms preprocess, 370.3ms inference, 3.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 4 cars, 1 motorcycle, 1 bench, 365.2ms
# Speed: 1.7ms preprocess, 365.2ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 4 cars, 1 motorcycle, 388.0ms
# Speed: 1.8ms preprocess, 388.0ms inference, 4.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 4 cars, 1 motorcycle, 408.0ms
# Speed: 1.4ms preprocess, 408.0ms inference, 4.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 4 cars, 1 motorcycle, 458.8ms
# Speed: 7.5ms preprocess, 458.8ms inference, 4.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 1 bicycle, 3 cars, 1 motorcycle, 369.3ms
# Speed: 2.5ms preprocess, 369.3ms inference, 4.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 3 cars, 1 motorcycle, 396.4ms
# Speed: 2.1ms preprocess, 396.4ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 3 cars, 1 motorcycle, 391.8ms
# Speed: 1.6ms preprocess, 391.8ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 2 cars, 1 motorcycle, 376.3ms
# Speed: 1.7ms preprocess, 376.3ms inference, 3.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 1 bicycle, 3 cars, 1 motorcycle, 371.5ms
# Speed: 2.0ms preprocess, 371.5ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 1 bicycle, 2 cars, 1 motorcycle, 371.4ms
# Speed: 1.9ms preprocess, 371.4ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 3 cars, 1 motorcycle, 351.3ms
# Speed: 1.7ms preprocess, 351.3ms inference, 5.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 2 cars, 1 motorcycle, 363.9ms
# Speed: 1.6ms preprocess, 363.9ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 1 bicycle, 1 car, 1 motorcycle, 410.5ms
# Speed: 1.5ms preprocess, 410.5ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 1 bicycle, 3 cars, 1 motorcycle, 1 bench, 378.7ms
# Speed: 2.1ms preprocess, 378.7ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 2 bicycles, 1 car, 1 motorcycle, 367.8ms
# Speed: 1.4ms preprocess, 367.8ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 11 persons, 2 bicycles, 2 cars, 1 motorcycle, 390.8ms
# Speed: 1.8ms preprocess, 390.8ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 2 bicycles, 2 cars, 1 motorcycle, 362.0ms
# Speed: 1.9ms preprocess, 362.0ms inference, 4.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 13 persons, 4 bicycles, 2 cars, 1 motorcycle, 371.8ms
# Speed: 1.7ms preprocess, 371.8ms inference, 4.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 13 persons, 3 bicycles, 2 cars, 1 motorcycle, 357.7ms
# Speed: 1.5ms preprocess, 357.7ms inference, 4.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 13 persons, 4 bicycles, 2 cars, 1 motorcycle, 354.4ms
# Speed: 1.6ms preprocess, 354.4ms inference, 4.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 13 persons, 3 bicycles, 3 cars, 1 motorcycle, 351.5ms
# Speed: 1.7ms preprocess, 351.5ms inference, 4.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 13 persons, 6 bicycles, 1 car, 1 motorcycle, 1 backpack, 345.6ms
# Speed: 1.5ms preprocess, 345.6ms inference, 5.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 13 persons, 4 bicycles, 1 motorcycle, 1 backpack, 409.5ms
# Speed: 1.5ms preprocess, 409.5ms inference, 4.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 12 persons, 4 bicycles, 1 car, 1 motorcycle, 357.4ms
# Speed: 1.7ms preprocess, 357.4ms inference, 4.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 3 bicycles, 2 cars, 1 motorcycle, 361.1ms
# Speed: 1.6ms preprocess, 361.1ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 6 bicycles, 2 cars, 318.0ms
# Speed: 1.6ms preprocess, 318.0ms inference, 4.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 4 bicycles, 2 cars, 332.6ms
# Speed: 1.3ms preprocess, 332.6ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 4 bicycles, 3 cars, 304.1ms
# Speed: 1.3ms preprocess, 304.1ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 10 persons, 4 bicycles, 3 cars, 1 bench, 318.7ms
# Speed: 1.3ms preprocess, 318.7ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 4 bicycles, 2 cars, 1 bench, 301.8ms
# Speed: 1.3ms preprocess, 301.8ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 9 persons, 3 bicycles, 2 cars, 1 bench, 308.8ms
# Speed: 1.3ms preprocess, 308.8ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 3 bicycles, 2 cars, 1 bench, 307.7ms
# Speed: 1.3ms preprocess, 307.7ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 4 bicycles, 3 cars, 1 bench, 342.7ms
# Speed: 11.7ms preprocess, 342.7ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 5 bicycles, 3 cars, 316.6ms
# Speed: 1.5ms preprocess, 316.6ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 4 bicycles, 3 cars, 304.0ms
# Speed: 1.3ms preprocess, 304.0ms inference, 2.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 5 bicycles, 3 cars, 309.9ms
# Speed: 1.3ms preprocess, 309.9ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 5 persons, 4 bicycles, 3 cars, 307.3ms
# Speed: 1.8ms preprocess, 307.3ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 5 persons, 4 bicycles, 3 cars, 369.5ms
# Speed: 1.4ms preprocess, 369.5ms inference, 3.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 5 persons, 4 bicycles, 3 cars, 1 bench, 319.3ms
# Speed: 1.3ms preprocess, 319.3ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 5 persons, 4 bicycles, 3 cars, 319.7ms
# Speed: 1.5ms preprocess, 319.7ms inference, 2.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 3 bicycles, 3 cars, 1 bench, 313.5ms
# Speed: 1.4ms preprocess, 313.5ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 5 persons, 2 bicycles, 4 cars, 325.1ms
# Speed: 1.3ms preprocess, 325.1ms inference, 2.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 5 persons, 2 bicycles, 3 cars, 1 handbag, 419.0ms
# Speed: 1.5ms preprocess, 419.0ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 3 bicycles, 3 cars, 307.0ms
# Speed: 1.8ms preprocess, 307.0ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 2 bicycles, 3 cars, 1 motorcycle, 307.2ms
# Speed: 1.6ms preprocess, 307.2ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 2 bicycles, 4 cars, 1 motorcycle, 321.2ms
# Speed: 1.4ms preprocess, 321.2ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 5 bicycles, 3 cars, 1 motorcycle, 317.0ms
# Speed: 1.4ms preprocess, 317.0ms inference, 3.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 2 bicycles, 3 cars, 1 motorcycle, 307.6ms
# Speed: 1.5ms preprocess, 307.6ms inference, 4.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 3 bicycles, 3 cars, 1 motorcycle, 317.3ms
# Speed: 1.4ms preprocess, 317.3ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 2 bicycles, 3 cars, 1 motorcycle, 307.6ms
# Speed: 1.4ms preprocess, 307.6ms inference, 2.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 2 bicycles, 4 cars, 2 motorcycles, 313.5ms
# Speed: 1.4ms preprocess, 313.5ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 2 bicycles, 3 cars, 1 motorcycle, 1 bench, 304.6ms
# Speed: 1.4ms preprocess, 304.6ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 2 bicycles, 1 car, 1 motorcycle, 321.3ms
# Speed: 1.5ms preprocess, 321.3ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 3 bicycles, 2 cars, 1 motorcycle, 1 handbag, 301.7ms
# Speed: 1.4ms preprocess, 301.7ms inference, 2.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 4 bicycles, 1 car, 1 motorcycle, 1 handbag, 324.7ms
# Speed: 1.4ms preprocess, 324.7ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 3 bicycles, 1 car, 1 motorcycle, 304.9ms
# Speed: 1.4ms preprocess, 304.9ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 2 bicycles, 1 car, 1 motorcycle, 332.4ms
# Speed: 1.4ms preprocess, 332.4ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 5 bicycles, 3 cars, 1 motorcycle, 2 handbags, 332.1ms
# Speed: 1.4ms preprocess, 332.1ms inference, 4.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 4 bicycles, 3 cars, 1 motorcycle, 1 handbag, 317.2ms
# Speed: 1.4ms preprocess, 317.2ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 4 bicycles, 2 cars, 1 motorcycle, 1 handbag, 313.3ms
# Speed: 1.4ms preprocess, 313.3ms inference, 3.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 3 bicycles, 3 cars, 1 motorcycle, 324.7ms
# Speed: 1.3ms preprocess, 324.7ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 2 bicycles, 2 cars, 1 motorcycle, 339.7ms
# Speed: 1.3ms preprocess, 339.7ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 3 bicycles, 1 car, 1 motorcycle, 314.6ms
# Speed: 1.9ms preprocess, 314.6ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 5 bicycles, 2 cars, 1 motorcycle, 326.0ms
# Speed: 1.6ms preprocess, 326.0ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 5 bicycles, 2 cars, 371.9ms
# Speed: 1.6ms preprocess, 371.9ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 5 bicycles, 2 cars, 307.7ms
# Speed: 1.4ms preprocess, 307.7ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 8 persons, 6 bicycles, 3 cars, 317.6ms
# Speed: 1.9ms preprocess, 317.6ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 4 bicycles, 4 cars, 1 motorcycle, 367.1ms
# Speed: 1.7ms preprocess, 367.1ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 5 bicycles, 4 cars, 1 backpack, 317.4ms
# Speed: 1.4ms preprocess, 317.4ms inference, 4.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 4 persons, 5 bicycles, 3 cars, 1 backpack, 339.7ms
# Speed: 1.9ms preprocess, 339.7ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 4 persons, 5 bicycles, 3 cars, 1 backpack, 389.4ms
# Speed: 1.5ms preprocess, 389.4ms inference, 3.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 7 persons, 5 bicycles, 1 car, 387.6ms
# Speed: 1.9ms preprocess, 387.6ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 3 bicycles, 2 cars, 1 backpack, 405.1ms
# Speed: 1.5ms preprocess, 405.1ms inference, 3.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 6 persons, 4 bicycles, 1 car, 1 backpack, 330.9ms
# Speed: 2.4ms preprocess, 330.9ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 4 persons, 5 bicycles, 1 car, 363.9ms
# Speed: 1.4ms preprocess, 363.9ms inference, 2.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 5 persons, 5 bicycles, 3 cars, 320.6ms
# Speed: 1.5ms preprocess, 320.6ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 3 persons, 4 bicycles, 1 car, 314.6ms
# Speed: 1.4ms preprocess, 314.6ms inference, 2.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 5 persons, 5 bicycles, 3 cars, 324.1ms
# Speed: 1.3ms preprocess, 324.1ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 4 persons, 4 bicycles, 2 cars, 308.5ms
# Speed: 1.3ms preprocess, 308.5ms inference, 2.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 4 persons, 2 bicycles, 3 cars, 310.1ms
# Speed: 1.8ms preprocess, 310.1ms inference, 2.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 4 persons, 2 bicycles, 3 cars, 1 bench, 309.2ms
# Speed: 1.3ms preprocess, 309.2ms inference, 3.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 4 persons, 1 bicycle, 4 cars, 311.5ms
# Speed: 1.4ms preprocess, 311.5ms inference, 2.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 3 persons, 2 bicycles, 4 cars, 336.8ms
# Speed: 1.9ms preprocess, 336.8ms inference, 2.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 3 persons, 2 bicycles, 3 cars, 323.2ms
# Speed: 1.7ms preprocess, 323.2ms inference, 2.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 2 persons, 1 bicycle, 5 cars, 339.2ms
# Speed: 1.5ms preprocess, 339.2ms inference, 2.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 3 persons, 1 bicycle, 3 cars, 326.9ms
# Speed: 1.4ms preprocess, 326.9ms inference, 2.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 3 persons, 1 bicycle, 2 cars, 324.8ms
# Speed: 1.4ms preprocess, 324.8ms inference, 2.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 2 persons, 3 cars, 333.0ms
# Speed: 1.4ms preprocess, 333.0ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 2 persons, 1 bicycle, 4 cars, 332.1ms
# Speed: 1.4ms preprocess, 332.1ms inference, 2.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 2 persons, 3 bicycles, 5 cars, 326.8ms
# Speed: 1.4ms preprocess, 326.8ms inference, 2.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 2 persons, 2 bicycles, 3 cars, 335.1ms
# Speed: 1.5ms preprocess, 335.1ms inference, 2.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 2 persons, 2 bicycles, 4 cars, 328.7ms
# Speed: 1.4ms preprocess, 328.7ms inference, 2.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 3 persons, 1 bicycle, 3 cars, 370.2ms
# Speed: 1.3ms preprocess, 370.2ms inference, 2.8ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 2 persons, 1 bicycle, 3 cars, 1 motorcycle, 371.8ms
# Speed: 1.6ms preprocess, 371.8ms inference, 2.3ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 2 persons, 3 cars, 1 motorcycle, 372.6ms
# Speed: 1.4ms preprocess, 372.6ms inference, 3.4ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 3 persons, 1 bicycle, 3 cars, 367.6ms
# Speed: 1.7ms preprocess, 367.6ms inference, 2.7ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 3 persons, 1 bicycle, 3 cars, 334.7ms
# Speed: 1.4ms preprocess, 334.7ms inference, 2.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 4 persons, 1 bicycle, 3 cars, 353.8ms
# Speed: 1.5ms preprocess, 353.8ms inference, 2.5ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 3 persons, 1 bicycle, 3 cars, 1 bench, 368.3ms
# Speed: 1.4ms preprocess, 368.3ms inference, 2.9ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 3 persons, 2 bicycles, 3 cars, 1 bench, 385.4ms
# Speed: 1.5ms preprocess, 385.4ms inference, 2.6ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 224x640 4 persons, 3 cars, 1 bench, 346.9ms
# Speed: 1.4ms preprocess, 346.9ms inference, 2.6ms postprocess per image at shape (1, 3, 224, 640)
# ------------------------------
# TOTAL FRAMES: 209
# TP=1467, FP=382, FN=1670
# ------------------------------
# Precision = 0.793
# Recall    = 0.468
# F1-Score  = 0.588
# mAP  = 0.417
# ------------------------------

# %% [markdown]
# # Step 3
# Implement the yolo model find the prediction with a kalman filter

# %% [markdown]
# # Make helper functions

# %%
# Here is the helper functions that is needed for the yolo model with the kalman filter
def iou_xyxy(box1, box2):
    # This function is to see how much two bounding boxes is overlapping
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])
    inter_area = max(0, x2 - x1) * max(0, y2 - y1)
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union_area = box1_area + box2_area - inter_area
    # The small value is to make sure the system does not get an error of devision by 0
    return inter_area / (union_area + 1e-9) 

def xyxy_to_cxcywh(box):
    # This function turns the bounding box from corner positions into center position, width and height
    w = box[2] - box[0]
    h = box[3] - box[1]
    cx = box[0] + w/2
    cy = box[1] + h/2
    return np.array([cx, cy, w, h])

def cxcywh_to_xyxy(cx, cy, w, h):
    # This function turns the bounding box from center position, width and height into corner positions 
    x1 = cx - w/2
    y1 = cy - h/2
    x2 = cx + w/2
    y2 = cy + h/2
    return [x1, y1, x2, y2] 

def associate_tracks_dets(tracks, dets_xyxy, dets_cls, iou_thresh=0.3):
    # This functions matches existing object tracks with new detections to see if the new detections matches the existing one
    if len(tracks) == 0:
        return [], [], list(range(len(dets_xyxy)))

    # IoU between tracktions and detections
    iou_matrix = np.zeros((len(tracks), len(dets_xyxy)), dtype=np.float32)
    for t, tr in enumerate(tracks):
        t_box = tr.get_xyxy()
        for d, d_box in enumerate(dets_xyxy):
            if tr.cls != dets_cls[d]:
                iou_matrix[t, d] = 0.0
            else:
                iou_matrix[t, d] = iou_xyxy(t_box, d_box)
                
    matches = []
    unmatched_tracks = set(range(len(tracks)))
    unmatched_dets = set(range(len(dets_xyxy)))

    # Make matching based on IoU
    if iou_matrix.size > 0:
        indices = np.dstack(np.unravel_index(np.argsort(-iou_matrix.ravel()), iou_matrix.shape))[0]
        for t, d in indices:
            if iou_matrix[t, d] < iou_thresh:
                break
            if t in unmatched_tracks and d in unmatched_dets:
                matches.append((t, d))
                unmatched_tracks.remove(t)
                unmatched_dets.remove(d)
                
    return matches, list(unmatched_tracks), list(unmatched_dets)

# %% [markdown]
# # Kalman filter function

# %%
class KalmanBoxTracker:
    # This class is the kalman filter for tracking the bounding boxes
    def __init__(self, init_z, cls, dt, init_velocity=None):
        #This function is for initializing the kalman filter
        
        self.dt = float(dt)

        #This is the state vector
        self.x = np.zeros((8,1), dtype=np.float32)
        
        self.x[0:4,0] = init_z.reshape(4) # initialize position and size
        if init_velocity is not None:
            self.x[4:8,0] = np.reshape(init_velocity, (4,)) # initialize velocity
        
        self.F = np.eye(8, dtype=np.float32) # State transition matrix
        for i in range(4): 
            self.F[i, i+4] = self.dt

        # Measurement matrix
        self.H = np.zeros((4,8), dtype=np.float32)
        self.H[0,0] = self.H[1,1] = self.H[2,2] = self.H[3,3] = 1.0

        # Uncertainty Covariance matrix
        self.P = np.eye(8, dtype=np.float32) * 10.0

        # Process noise 
        self.Q = np.eye(8, dtype=np.float32)
        self.Q[0,0]=0.5; self.Q[1,1]=0.5 # cx, cy
        self.Q[2,2]=0.1; self.Q[3,3]=0.1 # w, h
        self.Q[4,4]=2.0; self.Q[5,5]=2.0 # vx, vy
        self.Q[6,6]=1.0; self.Q[7,7]=1.0 # vm, vh

        # Measurement noise
        self.R = np.eye(4, dtype=np.float32) * 2.0
        self.R[2,2] = 10.0  # Increased noise for width measurement
        self.R[3,3] = 10.0  # Increased noise for height measurement
        
        # Identity matrix
        self.I = np.eye(8, dtype=np.float32)

        # Initialization of the needed data
        self.cls = cls # object class
        self.id = None # ID of the tracked object
        self.age = 0 # The number of frames since first detection
        self.miss = 0 # The number of frames where it is not seen
        self.score = 0.0 # The confidence of the detection
        self.hits = 0 # The number of times where it has been hit
        self.confirmed = False # Confirmation of the tracktion
        self.last_detection_box = cxcywh_to_xyxy(self.x[0,0], self.x[1,0], self.x[2,0], self.x[3,0])
        self.last_update_frame = -1

    def predict(self):
        # This function predict the next state 
        self.x = self.F @ self.x
        self.P = self.F @ self.P @ self.F.T + self.Q
        self.age += 1

        # Reset if the detection is missed
        if self.miss > 0:
            self.x[6, 0] = 0.0 # vw (velocity width)
            self.x[7, 0] = 0.0 # vh (velocity height)
            
        return self.get_xyxy()

    def update(self, z, score, frame_idx=None):
        # This is the update function of the kalman filter
        z = z.reshape(4,1)
        y = z - (self.H @ self.x)
        S = self.H @ self.P @ self.H.T + self.R
        K = self.P @ self.H.T @ np.linalg.inv(S)
        self.x = self.x + (K @ y)
        self.P = (self.I - K @ self.H) @ self.P
        
        self.miss = 0
        self.score = float(score)
        self.hits += 1
        if self.hits >= 2:
            self.confirmed = True
        
        self.last_detection_box = cxcywh_to_xyxy(float(self.x[0,0]), float(self.x[1,0]), 
                                                 float(self.x[2,0]), float(self.x[3,0]))
        self.last_update_frame = frame_idx if frame_idx is not None else self.last_update_frame

    def get_xyxy(self):
        # This function is to get the current bounding boxes
        cx = float(self.x[0,0]); cy = float(self.x[1,0])
        w = max(1.0, float(self.x[2,0])); h = max(1.0, float(self.x[3,0]))
        
        # This is to avoid unrealistic bounding boxes
        max_ratio = 10.0 
        
        if w > h * max_ratio: w = h * max_ratio
        if h > w * max_ratio: h = w * max_ratio
            
        return np.array(cxcywh_to_xyxy(cx, cy, w, h), dtype=np.float32)

# %%
# Here is the config for the object detection and tracking using both yolo and kalman filter
MODEL_PATH = "yolo11l.pt"
FPS = 30.0
DT = 1.0 / FPS
IOU_MATCH_THRESH = 0.5      
IOU_MERGE_CYCLIST = 0.2     
CENTER_DIST_GATING = 500.0    # High value allows jumping over large occlusions
INIT_CONF_THRESH = 0.65       # High threshold to prevent tracking noise
SCORE_DECAY = 0.98            # Very slow decay for long memory
PATIENTS = {"car": 80, "cyclist": 100, "pedestrian": 150}
MAX_INIT_PREV_DIST_SQ = 400.0**2
BOX_SIZE_THRESHOLDS = {
    "pedestrian": {"min": 50,  "max": 1000},    
    "car":        {"min": 2000, "max": 25000},   
    "cyclist":    {"min": 100, "max": 15000},   
}

# -------------------- MAIN --------------------
model = YOLO(MODEL_PATH)
allowed_classes = {"person", "car", "bicycle"}
TP, FP, FN = 0, 0, 0
tracks = []
next_id = 1
prev_frame_preds = [] 
tracked_results = [] # List to store output data

# Loop through images
for frame_id, frame_path in enumerate(images):
    frame = cv2.imread(frame_path)
    if frame is None: continue

    frame_disp = frame.copy() # This is for visualization

    # Ground truth
    frame_gt = labels[labels["frame"] == frame_id]
    gt_boxes = []
    for _, row in frame_gt.iterrows():
        cls = row["type"].lower()
        if cls in {"car", "pedestrian", "cyclist"}:
            gt_boxes.append([row["left"], row["top"], row["right"], row["bottom"]])
            # The ground truth drawing (Green boundin box)
            cv2.rectangle(frame_disp, (int(row["left"]), int(row["top"])),
                       (int(row["right"]), int(row["bottom"])), (0,255,0), 2)
            label = f"GT"
            cv2.putText(frame_disp, label, (int(row["left"]), int(row["top"])-5), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0,255,0), 1)


    # Start yolo detection
    results = model(frame, verbose=False)
    raw = []
    for r in results:
        boxes = r.boxes.xyxy.cpu().numpy() # Extracts the boundingbox coordinates into a numoy array
        confs = r.boxes.conf.cpu().numpy() # Extracsts the confidence of the detections
        clss = r.boxes.cls.cpu().numpy() # Extracts the class label for the detections
        
        for box, conf, cls_idx in zip(boxes, confs, clss):
            label = model.names[int(cls_idx)]
            if label in allowed_classes and float(conf) >= 0.3:
                raw.append((box, float(conf), label))
    
    # Filter by the size
    filtered = []
    for box, conf, label in raw:
        area = (box[2]-box[0]) * (box[3]-box[1])
        if label in BOX_SIZE_THRESHOLDS:
            if area < BOX_SIZE_THRESHOLDS[label]["min"] or area > BOX_SIZE_THRESHOLDS[label]["max"]:
                continue
        filtered.append((box, conf, label))
    raw = filtered

    # Make the cyclists based on a person on top of a bicycle
    used = set()
    preds = []
    for i, (b1, c1, l1) in enumerate(raw):
        if l1 != "person": continue
        for j, (b2, c2, l2) in enumerate(raw):
            if l2 != "bicycle" or j in used: continue
            if iou_xyxy(b1, b2) > IOU_MERGE_CYCLIST:
                # Make it into one big bounding box around the cyclist
                x1 = min(b1[0], b2[0]); y1 = min(b1[1], b2[1])
                x2 = max(b1[2], b2[2]); y2 = max(b1[3], b2[3])
                preds.append(([x1, y1, x2, y2], (c1+c2)/2, "cyclist"))
                used.add(i); used.add(j)
                
    # Add the other detections
    for k, (box, conf, label) in enumerate(raw):
        if k in used: continue
        if label == "car": preds.append((list(map(int, box)), conf, "car"))
        elif label == "person": preds.append((list(map(int, box)), conf, "pedestrian"))

    # Start the predictions with the kalman filter
    for tr in tracks: tr.predict()

    # Match the detections to the tracking
    dets_xyxy = [np.array(b, dtype=np.float32) for b, c, l in preds]
    dets_cls = [l for b, c, l in preds]
    dets_z = [xyxy_to_cxcywh(b) for b, c, l in preds]
    matches, unmatched_tracks, unmatched_dets = associate_tracks_dets(tracks, dets_xyxy, dets_cls, IOU_MATCH_THRESH)

    # Start the update with the kalman filter
    for t, d in matches:
        tracks[t].update(dets_z[d], preds[d][1], frame_id)
        tracks[t].cls = dets_cls[d]

    # Remove the matches that is not correct
    for t in unmatched_tracks:
        tr = tracks[t]
        tr.miss += 1
        tr.score *= SCORE_DECAY

        if tr.miss > PATIENTS.get(tr.cls, 60) or tr.score < 0.05:
            tracks[t] = None

    tracks = [t for t in tracks if t is not None]

    # Start new tracking
    prev_by_cls = {}
    for p in prev_frame_preds: prev_by_cls.setdefault(p["cls"], []).append(p)

    for d in unmatched_dets:
        if preds[d][1] < INIT_CONF_THRESH: continue
        box = dets_xyxy[d]
        # Remove dublicates
        if any(iou_xyxy(t.get_xyxy(), box) > 0.5 for t in tracks): continue
        
        init_vel = None
        cls = dets_cls[d]
        if cls in prev_by_cls:
            cx, cy, _, _ = dets_z[d]
            # Estimate the velocity
            best = min(prev_by_cls[cls], key=lambda p: (cx-p["cx"])**2 + (cy-p["cy"])**2, default=None)
            if best:
                d2 = (cx-best["cx"])**2 + (cy-best["cy"])**2
                if d2 < MAX_INIT_PREV_DIST_SQ:
                    init_vel = [(cx-best["cx"])/DT, (cy-best["cy"])/DT, 0.0, 0.0]
                    
        # Create the new tracktion
        tr = KalmanBoxTracker(dets_z[d], cls, DT, init_vel)
        tr.id = next_id; next_id += 1
        tr.score = preds[d][1]
        tracks.append(tr)

    # Remove the overlapping tracktions
    to_rem = set()
    for i in range(len(tracks)):
        if i in to_rem: continue
        for j in range(i+1, len(tracks)):
            if j in to_rem: continue
            if iou_xyxy(tracks[i].get_xyxy(), tracks[j].get_xyxy()) > 0.4:
                if tracks[i].confirmed != tracks[j].confirmed:
                    to_rem.add(j if tracks[i].confirmed else i)
                else:
                    to_rem.add(j if tracks[i].score > tracks[j].score else i)
    tracks = [t for k, t in enumerate(tracks) if k not in to_rem]
    
    #Start the evaluation and the visualization
    EVAL_SCORE_THRESH = 0.3
    eval_tracks = [t for t in tracks if t.score > EVAL_SCORE_THRESH]
    
    matched_gt_indices = set()
    
    for tr in eval_tracks:
        box = tr.get_xyxy().astype(int)
        pred_box = tr.get_xyxy()
        best_iou = 0
        best_gt_idx = -1
        for idx, gt_box in enumerate(gt_boxes):
            iou = iou_xyxy(pred_box, gt_box)
            if iou > best_iou:
                best_iou = iou
                best_gt_idx = idx
        
        # Drawing
        is_tp = best_iou >= 0.5
        is_active = tr.miss == 0
        
        color = (0, 0, 255) # Predicted bounding boxes is red
        
        if is_tp:
            TP += 1
            matched_gt_indices.add(best_gt_idx)
            label = f"ID:{tr.id} S:{tr.score:.2f} [Predicted]"
            
        elif not is_tp and is_active:
            FP += 1
            

        # Save data
        tracked_results.append({
            'frame': frame_id,
            'id': tr.id,
            'class': tr.cls,
            'score': tr.score,
            'left': box[0],
            'top': box[1],
            'right': box[2],
            'bottom': box[3],
            'metric_status': 'TP' if is_tp else 'FP'
        })

        # Draw the evaluated track 
        cv2.rectangle(frame_disp, (box[0], box[1]), (box[2], box[3]), color, 2)
        cv2.putText(frame_disp, label, (box[0], box[1]-5), cv2.FONT_HERSHEY_SIMPLEX, 0.4, color, 1)
    
    
    FN += len(gt_boxes) - len(matched_gt_indices)

    # Save for next velocity
    prev_frame_preds = []
    for box, conf, cls in preds:
        z = xyxy_to_cxcywh(np.array(box))
        prev_frame_preds.append({"cx": z[0], "cy": z[1], "w": z[2], "h": z[3], "cls": cls})

    cv2.imshow("Tracker", frame_disp)
    if cv2.waitKey(1) == 27: break

cv2.destroyAllWindows()

# Print the evaluation and save the results
results_df = pd.DataFrame(tracked_results)
results_df.to_csv('tracked_results.csv', index=False)
print("Tracked results saved to tracked_results.csv")

# Print Metrics
precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1_score = 2 * (precision * recall) / (precision + recall) if precision + recall > 0 else 0.0
mAP = TP/(TP+FP+FN)

print("-" * 30)
print(f"TOTAL FRAMES: {frame_id + 1}")
print(f"TP={TP}, FP={FP}, FN={FN}")
print("-" * 30)
print(f"Precision = {precision:.3f}")
print(f"Recall    = {recall:.3f}")
print(f"F1-Score  = {f1_score:.3f}")
print(f"mAP  = {mAP:.3f}")
print("-" * 30)
# Out:
# Tracked results saved to tracked_results.csv
# ------------------------------
# TOTAL FRAMES: 209
# TP=1577, FP=314, FN=1561
# ------------------------------
# Precision = 0.834
# Recall    = 0.503
# F1-Score  = 0.627
# mAP  = 0.457
# ------------------------------

# %% [markdown]
# # Stereo vision
#
# Load the camera calibraation, compute the disparity and estimate 3D coordinates

# %%
# Load files (Change paths if needed)
left_folder = "34759_final_project_rect/seq_02/image_02/data/"
right_folder = "34759_final_project_rect/seq_02/image_03/data/"
calib_path = "34759_final_project_rect/calib_cam_to_cam.txt"

def load_projection_matrices(calib_file):
    # Load the projection from the calibration file
    P = {}
    with open(calib_file, "r") as f:
        for line in f:
            line = line.strip()
            if line.startswith("P_rect_"):
                key, values = line.split(":")
                cam = int(key.split("_")[-1])
                P[cam] = np.array(list(map(float, values.split()))).reshape(3,4)
    return P

P = load_projection_matrices(calib_path)
P_left = P[2]   # P_rect_02
P_right = P[3]  # P_rect_03

f = P_left[0,0]               # focale in pixel
B = abs(P_right[0,3] / f)     # baseline = Tx / f
print(f"Focale: {f:.2f} px, Baseline: {B:.3f} m")

np.set_printoptions(precision=15, suppress=False)
print("P_left (02):\n", P_left)
print("P_right (03):\n", P_right)

def compute_disparity_map(left_img, right_img):
    # Compute the disparity map between the left and right image
    left_gray = cv2.cvtColor(left_img, cv2.COLOR_BGR2GRAY)
    right_gray = cv2.cvtColor(right_img, cv2.COLOR_BGR2GRAY)
    
    # SGBM parameters
    min_disp = 0
    num_disp = 64 
    block_size = 9
    
    stereo = cv2.StereoSGBM_create(
        minDisparity=min_disp, 
        numDisparities=num_disp, 
        blockSize=block_size, 
        P1=8 * 3 * block_size**2,
        P2=32 * 3 * block_size**2,
        disp12MaxDiff=1,
        uniquenessRatio=10,
        speckleWindowSize=100,
        speckleRange=32
    )
    
    disparity = stereo.compute(left_gray, right_gray).astype(np.float32) / 16.0
    disparity[disparity < 0] = np.nan 
    
    return disparity

def estimate_depth_from_disparity(disparity_map, bbox):
    # Estimate the depth Z
    left, top, right, bottom = [int(x) for x in bbox]
    
    h, w = disparity_map.shape
    top = max(0, top); bottom = min(h, bottom)
    left = max(0, left); right = min(w, right)
    
    disp_region = disparity_map[top:bottom, left:right]
    valid_disparities = disp_region[~np.isnan(disp_region)]
    
    if len(valid_disparities) < 10:
        return -1.0 
        
    median_disparity = np.median(valid_disparities)
    
    if median_disparity <= 1e-6:
        return -1.0 
        
    Z_pred = BASELINE_X_FX / median_disparity
    
    return Z_pred

def project_3d_to_2d(X_c, Y_c, Z_c, FX, FY, CX, CY):
    #Projects a 3D point (X, Y, Z) to 2D image coordinates (u, v)
    if Z_c <= 0: return None, None
        
    u = int((X_c * FX / Z_c) + CX)
    v = int((Y_c * FY / Z_c) + CY)
    
    return u, v


def calculate_pred_3d_bottom_center(track_row, Z_pred):
    # Calculates the 3D center corresponding to the 2D bounding box bottom
    if Z_pred <= 0:
        return None
        
    # 2D bottom center
    u_c = (track_row["left"] + track_row["right"]) / 2 # horizontal center
    v_bottom = track_row["bottom"]                     # vertical bottom edge
    
    X_pred = Z_pred * (u_c - CX) / FX
    
    Y_pred = Z_pred * (v_bottom - CY) / FY
    
    return [X_pred, Y_pred, Z_pred]
# Out:
# Focale: 707.05 px, Baseline: 0.473 m
# P_left (02):
#  [[ 7.070493e+02  0.000000e+00  6.040814e+02  4.575831e+01]
#  [ 0.000000e+00  7.070493e+02  1.805066e+02 -3.454157e-01]
#  [ 0.000000e+00  0.000000e+00  1.000000e+00  4.981016e-03]]
# P_right (03):
#  [[ 7.070493e+02  0.000000e+00  6.040814e+02 -3.341081e+02]
#  [ 0.000000e+00  7.070493e+02  1.805066e+02  2.330660e+00]
#  [ 0.000000e+00  0.000000e+00  1.000000e+00  3.201153e-03]]

# %% [markdown]
# # Visualization for 3D tracking
# This code make a visualization of the 3D tracking with ground truth and the predictions from kalman filter and yolo model

# %%
# Path for import of images, labels, the tracktion and the calibration
IMG_FOLDER_LEFT = "34759_final_project_rect/seq_02/image_02/data"
IMG_FOLDER_RIGHT = "34759_final_project_rect/seq_02/image_03/data" 
LABEL_FILE = "34759_final_project_rect/seq_02/labels.txt"
TRACK_FILE_PATH = "tracked_results.csv"
CALIB_FILE_PATH = "34759_final_project_rect/calib_cam_to_cam.txt"

# Set the global parameters
FX = 707.0493
FY = 707.0493
CX = 604.0814
CY = 180.5066
BASELINE_X_FX = 45.75831 

# Visualization Colors
COLOR_PREDICTED_BOX = (255, 0, 0)       # Blue box for 2D track
COLOR_GT_POINT = (0, 255, 0)            # Green point for Ground Truth 3D center (BOTTOM)
COLOR_PRED_3D_POINT = (0, 0, 255)       # Red point for Predicted 3D center (BOTTOM)

# Load data
cols = ["frame","track_id","type","truncated","occluded","alpha",
        "left","top","right","bottom",
        "height","width","length",
        "x","y","z","rot_y"]

try:
    # Load Ground Truth data 
    labels = pd.read_csv(LABEL_FILE, sep=" ", names=cols)
    
    # Load Predicted Tracks data
    df_tracks = pd.read_csv(TRACK_FILE_PATH)

    if 'frame' not in df_tracks.columns:
        alternative_frame_name = 'Frame' 
        if alternative_frame_name in df_tracks.columns:
            df_tracks = df_tracks.rename(columns={alternative_frame_name: 'frame'})
        elif 'frame' not in df_tracks.columns:
             raise KeyError("'frame'") 
            
except KeyError as e:
    print(f"KeyError: Required column {e} is missing. Please check your {TRACK_FILE_PATH} file content.")
    exit()
except FileNotFoundError as e:
    print(f"Error: {e}. Please ensure files exist and the paths are correct.")
    exit()

allowed_gt_classes = ["Car", "Pedestrian", "Cyclist"]
labels_seq = labels[labels["type"].isin(allowed_gt_classes)].copy()
labels_seq.loc[:, 'type'] = labels_seq['type'].str.lower()
labels_seq_grouped = labels_seq.groupby('frame')
tracks_grouped = df_tracks.groupby('frame')

images_left = sorted(glob.glob(os.path.join(IMG_FOLDER_LEFT, "*.png")))
images_right = sorted(glob.glob(os.path.join(IMG_FOLDER_RIGHT, "*.png")))

if not images_left or len(images_left) != len(images_right):
    raise FileNotFoundError("Image files missing or count mismatch.")

print(f"Loaded {len(images_left)} frames for visualization.")

# Visualization

for frame_id, img_path_left in enumerate(tqdm(images_left, desc="Generating Visualization")):
    img_path_right = images_right[frame_id]
    
    frame_left = cv2.imread(img_path_left)
    frame_right = cv2.imread(img_path_right)
    
    if frame_left is None or frame_right is None:
        continue

    frame_disp = frame_left.copy()
    
    # Compute Disparity Map
    disparity_map = compute_disparity_map(frame_left, frame_right)

    # Draw Ground Truth 3D Centers (Red Dot)
    if frame_id in labels_seq_grouped.groups:
        frame_gt = labels_seq_grouped.get_group(frame_id)
        
        for _, row in frame_gt.iterrows():
            X_c, Y_c, Z_c = row["x"], row["y"], row["z"]
            gt_cls = row['type']
            
            # Project GT 3D center (the bottom point) to 2D image coordinates
            u, v = project_3d_to_2d(X_c, Y_c, Z_c, FX, FY, CX, CY)
            
            if u is not None:
                # Draw Red GT dot
                cv2.circle(frame_disp, (u, v), 5, COLOR_GT_POINT, -1)
                
                # Label with X, Y, Z position (in meters)
                gt_label_line1 = f"GT (BOTTOM): {gt_cls}"
                gt_label_line2 = f"X:{X_c:.1f} Y:{Y_c:.1f}"
                gt_label_line3 = f"Z:{Z_c:.1f} m"
                
                # Draw labels 
                cv2.putText(frame_disp, gt_label_line1, (u + 10, v - 15), cv2.FONT_HERSHEY_SIMPLEX, 0.4, COLOR_GT_POINT, 1)
                cv2.putText(frame_disp, gt_label_line2, (u + 10, v), cv2.FONT_HERSHEY_SIMPLEX, 0.4, COLOR_GT_POINT, 1)
                cv2.putText(frame_disp, gt_label_line3, (u + 10, v + 15), cv2.FONT_HERSHEY_SIMPLEX, 0.4, COLOR_GT_POINT, 1)


    # Draw Predicted 2D Boxes and Predicted 3D BOTTOM Centers (Blue Box & Green Dot)
    if frame_id in tracks_grouped.groups:
        frame_tracks = tracks_grouped.get_group(frame_id)
        
        for _, track_row in frame_tracks.iterrows():
            if not all(col in track_row for col in ["left", "top", "right", "bottom", "id", "class"]):
                continue

            bbox = [track_row["left"], track_row["top"], track_row["right"], track_row["bottom"]]
            track_id = int(track_row['id'])
            cls = track_row['class']
            
            # Depth estimation
            Z_pred_val = estimate_depth_from_disparity(disparity_map, bbox)
            
            # Use the function to estimate the 3D center corresponding to the 2D bottom edge
            pred_3d_center = calculate_pred_3d_bottom_center(track_row, Z_pred_val)
            
            # Draw yolo + kalman filter bounding box
            box_int = [int(x) for x in bbox]
            cv2.rectangle(frame_disp, (box_int[0], box_int[1]), (box_int[2], box_int[3]), COLOR_PREDICTED_BOX, 2)
            
            box_label = f"P:{cls} ID:{track_id}"
            cv2.putText(frame_disp, box_label, (box_int[0], box_int[1]-5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLOR_PREDICTED_BOX, 1)

            # Draw predicted position
            if pred_3d_center is not None:
                X_pred, Y_pred, Z_pred = pred_3d_center
                
                # Project Predicted 3D center (the BOTTOM point) to 2D image coordinates
                u_pred, v_pred = project_3d_to_2d(X_pred, Y_pred, Z_pred, FX, FY, CX, CY)
                
                if u_pred is not None:
                    # Draw Green Predicted dot
                    cv2.circle(frame_disp, (u_pred, v_pred), 5, COLOR_PRED_3D_POINT, -1)
                    
                    # Label with X, Y, Z position (in meters)
                    pred_label_line1 = f"PRED (BOTTOM):"
                    pred_label_line2 = f"X:{X_pred:.1f} Y:{Y_pred:.1f}"
                    pred_label_line3 = f"Z:{Z_pred:.1f} m"
                    
                    # Draw labels 
                    cv2.putText(frame_disp, pred_label_line1, (u_pred + 10, v_pred - 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLOR_PRED_3D_POINT, 1)
                    cv2.putText(frame_disp, pred_label_line2, (u_pred + 10, v_pred - 15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLOR_PRED_3D_POINT, 1)
                    cv2.putText(frame_disp, pred_label_line3, (u_pred + 10, v_pred), cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLOR_PRED_3D_POINT, 1)

    # Display the frame
    cv2.imshow("3D Tracking Visualization (Green=Predicted BOTTOM, Red=GT BOTTOM)", frame_disp)

    if frame_id == 0:
        # Show first frame for 30 seconds (30000 ms) for the video
        key = cv2.waitKey(30000)
    else:
        # Show subsequent frames for 50 ms
        key = cv2.waitKey(50)

    if key == 27:  # ESC key to exit
        break

cv2.destroyAllWindows()
# Out:
# Loaded 209 frames for visualization.
# Generating Visualization: 100%|██████████████████████████████████████████████████████| 209/209 [01:09<00:00,  3.00it/s]

# %% [markdown]
# # Validation of the 3D positions

# %%
results = [] # This array will be filled with the ground truth and the predicted results

for frame_id in range(len(images_left)):
    # Ground truth objects in this frame
    frame_gt = labels_seq_grouped.get_group(frame_id) if frame_id in labels_seq_grouped.groups else pd.DataFrame(columns=cols)
    # Predicted tracks in this frame
    frame_tracks = tracks_grouped.get_group(frame_id) if frame_id in tracks_grouped.groups else pd.DataFrame()

    # Iterate over ground truth objects
    for _, gt_row in frame_gt.iterrows():
        gt_id = gt_row["track_id"]
        gt_cls = gt_row["type"]
        gt_x, gt_y, gt_z = gt_row["x"], gt_row["y"], gt_row["z"]

        if not frame_tracks.empty:
            # Loop through predictions in this frame
            for _, track_row in frame_tracks.iterrows():
                pred_id = int(track_row["id"])
                pred_cls = track_row["class"]

                bbox = [track_row["left"], track_row["top"], track_row["right"], track_row["bottom"]]
                Z_pred_val = estimate_depth_from_disparity(disparity_map, bbox)
                pred_3d_center = calculate_pred_3d_bottom_center(track_row, Z_pred_val)

                if pred_3d_center is not None:
                    X_pred, Y_pred, Z_pred = pred_3d_center
                else:
                    X_pred, Y_pred, Z_pred = None, None, None

                results.append({
                    "frame": frame_id,
                    "gt_id": gt_id,
                    "gt_class": gt_cls,
                    "gt_x": gt_x,
                    "gt_y": gt_y,
                    "gt_z": gt_z,
                    "pred_id": pred_id,          
                    "pred_class": pred_cls,
                    "pred_x": X_pred,
                    "pred_y": Y_pred,
                    "pred_z": Z_pred
                })
        else:
            # No predictions at all for this ground truth 
            results.append({
                "frame": frame_id,
                "gt_id": gt_id,
                "gt_class": gt_cls,
                "gt_x": gt_x,
                "gt_y": gt_y,
                "gt_z": gt_z,
                "pred_id": None,
                "pred_class": None,
                "pred_x": None,
                "pred_y": None,
                "pred_z": None
            })

df_validation = pd.DataFrame(results)
print(df_validation.head(20))
df_validation.to_csv("validation_results.csv", index=False)
print("Validation results saved to validation_results.csv")
# Out:
#     frame  gt_id gt_class       gt_x      gt_y       gt_z  pred_id  \
# 0       0      0      car  19.260260  1.775559  24.510190        1
# 1       0      0      car  19.260260  1.775559  24.510190        2
# 2       0      0      car  19.260260  1.775559  24.510190        3
# 3       0      0      car  19.260260  1.775559  24.510190        4
# 4       0      0      car  19.260260  1.775559  24.510190        5
# 5       0      0      car  19.260260  1.775559  24.510190        6
# 6       0      0      car  19.260260  1.775559  24.510190        7
# 7       0      0      car  19.260260  1.775559  24.510190        8
# 8       0      1      car  16.289924  1.602928  23.743018        1
# 9       0      1      car  16.289924  1.602928  23.743018        2
# 10      0      1      car  16.289924  1.602928  23.743018        3
# 11      0      1      car  16.289924  1.602928  23.743018        4
# 12      0      1      car  16.289924  1.602928  23.743018        5
# 13      0      1      car  16.289924  1.602928  23.743018        6
# 14      0      1      car  16.289924  1.602928  23.743018        7
# 15      0      1      car  16.289924  1.602928  23.743018        8
# 16      0      2      car  13.738582  1.691811  24.225602        1
# 17      0      2      car  13.738582  1.691811  24.225602        2
# 18      0      2      car  13.738582  1.691811  24.225602        3
# 19      0      2      car  13.738582  1.691811  24.225602        4
#
#     pred_class    pred_x    pred_y    pred_z
# 0      cyclist -0.754404  0.431149  2.354125
# 1          car  2.091573  0.173949  2.964101
# 2   pedestrian -2.268959  0.224413  4.231982
# 3   pedestrian -0.820220  0.411276  4.067405
# 4   pedestrian -2.197744  0.236729  4.464225
# 5          car  2.388067  0.181074  3.012893
# 6   pedestrian -2.095034  0.319340  4.754110
# 7          car  1.726155  0.171143  2.988298
# 8      cyclist -0.754404  0.431149  2.354125
# 9          car  2.091573  0.173949  2.964101
# 10  pedestrian -2.268959  0.224413  4.231982
# 11  pedestrian -0.820220  0.411276  4.067405
# 12  pedestrian -2.197744  0.236729  4.464225
# 13         car  2.388067  0.181074  3.012893
# 14  pedestrian -2.095034  0.319340  4.754110
# 15         car  1.726155  0.171143  2.988298
# 16     cyclist -0.754404  0.431149  2.354125
# 17         car  2.091573  0.173949  2.964101
# 18  pedestrian -2.268959  0.224413  4.231982
# 19  pedestrian -0.820220  0.411276  4.067405
# Validation results saved to validation_results.csv

# %%
# Normalize the classes
if "gt_class" in df_validation.columns:
    df_validation["gt_class"] = df_validation["gt_class"].str.lower()
if "pred_class" in df_validation.columns:
    df_validation["pred_class"] = df_validation["pred_class"].str.lower()

# Map the classes
CLASS_MAP = {
    "car": "car",
    "cyclist": "cyclist",
    "bicycle": "cyclist",
    "ped": "pedestrian",
    "person": "pedestrian",
    "pedestrian": "pedestrian"
}
# Helper for mapping the classes 
def map_class(c):
    if pd.isna(c):
        return None
    c = str(c).lower().strip()
    return CLASS_MAP.get(c, c)

# Apply mapping to both ground truth and predictions
df_validation["gt_class_norm"] = df_validation["gt_class"].apply(map_class)
df_validation["pred_class_norm"] = df_validation["pred_class"].apply(map_class)

# Helper to check for axis errors
def compute_axis_errors(gt_x, gt_y, gt_z, pred_x, pred_y, pred_z):
    return (gt_x - pred_x), (gt_y - pred_y), (gt_z - pred_z)

grouped = df_validation.groupby(["gt_id", "gt_class_norm"])
summary_rows = []

for (gt_id, gt_cls), group in grouped:
    # Filter to valid predictions and same class
    group_valid = group.dropna(subset=["pred_id", "pred_x", "pred_y", "pred_z"]).copy()
    group_valid = group_valid[group_valid["pred_class_norm"] == gt_cls]
    
    # For each frame, keep only the prediction with smallest Euclidean error
    best_preds = []
    for frame_id, frame_group in group_valid.groupby("frame"):
        candidates = []
        for _, row in frame_group.iterrows():
            gt_x, gt_y, gt_z = float(row["gt_x"]), float(row["gt_y"]), float(row["gt_z"])
            pred_x, pred_y, pred_z = float(row["pred_x"]), float(row["pred_y"]), float(row["pred_z"])
            err_x, err_y, err_z = compute_axis_errors(gt_x, gt_y, gt_z, pred_x, pred_y, pred_z)
            euclid = np.sqrt(err_x**2 + err_y**2 + err_z**2)
            candidates.append((euclid, row, err_x, err_y, err_z))
        if candidates:
            best_preds.append(min(candidates, key=lambda x: x[0]))

    num_frames_matched = len(best_preds)

    if num_frames_matched == 0:
        # No valid predictions for this ground truth across all frames
        any_row = group.iloc[0]
        print(f"\nGT {gt_cls} (ID={gt_id}) at ({float(any_row['gt_x']):.2f}, {float(any_row['gt_y']):.2f}, {float(any_row['gt_z']):.2f}) over all frames has 0 predictions:")
        summary_rows.append({
            "gt_id": gt_id,
            "gt_class": gt_cls,
            "frames_matched": 0,
            "mae_x": np.nan,
            "mae_y": np.nan,
            "mae_z": np.nan,
            "mean_euclid": np.nan
        })
        continue

    # Collect signed errors per frame
    errors_x, errors_y, errors_z, euclids = [], [], [], []

    header_gt_x = float(best_preds[0][1]["gt_x"])
    header_gt_y = float(best_preds[0][1]["gt_y"])
    header_gt_z = float(best_preds[0][1]["gt_z"])
    print(f"\nGT {gt_cls} (ID={gt_id}) at ({header_gt_x:.2f}, {header_gt_y:.2f}, {header_gt_z:.2f}) over all frames has {num_frames_matched} matched predictions:")

    for euclid, row, err_x, err_y, err_z in best_preds:
        pred_id = int(row["pred_id"])
        pred_x, pred_y, pred_z = float(row["pred_x"]), float(row["pred_y"]), float(row["pred_z"])

        # Print signed errors per axis for this frame
        print(f"  - Frame {int(row['frame'])}, Pred ID={pred_id}, class={row['pred_class_norm']}, "
              f"pos=({pred_x:.2f}, {pred_y:.2f}, {pred_z:.2f}), "
              f"error_x={err_x:.2f}, error_y={err_y:.2f}, error_z={err_z:.2f}, euclid={euclid:.2f}")

        errors_x.append(err_x); errors_y.append(err_y); errors_z.append(err_z); euclids.append(euclid)

    # Report MAE (mean absolute error) per axis and mean euclidean error across frames
    mae_x = float(np.mean(np.abs(errors_x)))
    mae_y = float(np.mean(np.abs(errors_y)))
    mae_z = float(np.mean(np.abs(errors_z)))
    mean_euclid = float(np.mean(euclids))

    print(f"  => MAE for GT ID={gt_id}: x={mae_x:.2f}, y={mae_y:.2f}, z={mae_z:.2f} | mean_euclid={mean_euclid:.2f}")

    summary_rows.append({
        "gt_id": gt_id,
        "gt_class": gt_cls,
        "frames_matched": num_frames_matched,
        "mae_x": mae_x,
        "mae_y": mae_y,
        "mae_z": mae_z,
        "mean_euclid": mean_euclid
    })

# Save the summery table
df_summary = pd.DataFrame(summary_rows).sort_values(["gt_class", "gt_id"])
df_summary.to_csv("gt_error_summary.csv", index=False)
print("\n Saved per-GT error summary to gt_error_summary.csv")

# Predictions with no ground truth or class mismatch
gt_keys = set(df_validation[["frame", "gt_id", "gt_class_norm"]].dropna().apply(tuple, axis=1))
pred_rows = df_validation.dropna(subset=["pred_id", "pred_x", "pred_y", "pred_z"])

preds_no_gt = []
preds_class_mismatch = []

for _, row in pred_rows.iterrows():
    key = (row["frame"], row["gt_id"], row["gt_class_norm"])
    if pd.isna(row["gt_id"]) or key not in gt_keys:
        preds_no_gt.append(row)
    else:
        if row["pred_class_norm"] != row["gt_class_norm"]:
            preds_class_mismatch.append(row)

if len(preds_no_gt) == 0:
    print("\nNo predictions without GT correspondence.")
else:
    print("\nPredictions with no GT correspondence:")
    for _, r in pd.DataFrame(preds_no_gt).iterrows():
        print(f"  - Frame {int(r['frame'])}, Pred ID={int(r['pred_id'])}, class={r['pred_class_norm']}, "
              f"pos=({float(r['pred_x']):.2f}, {float(r['pred_y']):.2f}, {float(r['pred_z']):.2f})")

if len(preds_class_mismatch) == 0:
    print("\nNo predictions with class mismatch against GT.")
else:
    print("\nPredictions with class mismatch against GT:")
    for _, r in pd.DataFrame(preds_class_mismatch).iterrows():
        print(f"  - Frame {int(r['frame'])}, GT ID={int(r['gt_id'])}, GT class={r['gt_class_norm']} "
              f"=> Pred ID={int(r['pred_id'])}, Pred class={r['pred_class_norm']}, "
              f"pos=({float(r['pred_x']):.2f}, {float(r['pred_y']):.2f}, {float(r['pred_z']):.2f})")
# Out:
# GT car (ID=0) at (19.26, 1.78, 24.51) over all frames has 209 matched predictions:
#   - Frame 0, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.87, error_y=1.59, error_z=21.50, euclid=27.37
#   - Frame 1, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.87, error_y=1.59, error_z=21.50, euclid=27.37
#   - Frame 2, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.87, error_y=1.59, error_z=21.50, euclid=27.37
#   - Frame 3, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.87, error_y=1.59, error_z=21.50, euclid=27.37
#   - Frame 4, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.88, error_y=1.59, error_z=21.51, euclid=27.39
#   - Frame 5, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.88, error_y=1.59, error_z=21.51, euclid=27.39
#   - Frame 6, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.88, error_y=1.59, error_z=21.51, euclid=27.39
#   - Frame 7, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.87, error_y=1.59, error_z=21.50, euclid=27.37
#   - Frame 8, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.87, error_y=1.59, error_z=21.49, euclid=27.37
#   - Frame 9, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.88, error_y=1.59, error_z=21.51, euclid=27.38
#   - Frame 10, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.87, error_y=1.59, error_z=21.49, euclid=27.37
#   - Frame 11, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.87, error_y=1.59, error_z=21.51, euclid=27.38
#   - Frame 12, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.87, error_y=1.59, error_z=21.51, euclid=27.38
#   - Frame 13, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.87, error_y=1.59, error_z=21.51, euclid=27.38
#   - Frame 14, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.87, error_y=1.59, error_z=21.51, euclid=27.38
#   - Frame 15, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.87, error_y=1.59, error_z=21.51, euclid=27.38
#   - Frame 16, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.87, error_y=1.59, error_z=21.50, euclid=27.38
#   - Frame 17, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.87, error_y=1.59, error_z=21.50, euclid=27.38
#   - Frame 18, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.87, error_y=1.59, error_z=21.50, euclid=27.38
#   - Frame 19, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.86, error_y=1.59, error_z=21.49, euclid=27.36
#   - Frame 20, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.86, error_y=1.59, error_z=21.49, euclid=27.36
#   - Frame 21, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.86, error_y=1.59, error_z=21.49, euclid=27.36
#   - Frame 22, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.86, error_y=1.58, error_z=21.49, euclid=27.36
#   - Frame 23, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.86, error_y=1.58, error_z=21.49, euclid=27.36
#   - Frame 24, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.87, error_y=1.58, error_z=21.50, euclid=27.37
#   - Frame 25, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.87, error_y=1.58, error_z=21.50, euclid=27.37
#   - Frame 26, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=16.87, error_y=1.58, error_z=21.50, euclid=27.37
#   - Frame 27, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.86, error_y=1.58, error_z=21.49, euclid=27.36
#   - Frame 28, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.86, error_y=1.58, error_z=21.49, euclid=27.36
#   - Frame 29, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.86, error_y=1.58, error_z=21.49, euclid=27.36
#   - Frame 30, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.84, error_y=1.58, error_z=21.46, euclid=27.33
#   - Frame 31, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.84, error_y=1.58, error_z=21.46, euclid=27.33
#   - Frame 32, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.86, error_y=1.58, error_z=21.49, euclid=27.36
#   - Frame 33, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.84, error_y=1.58, error_z=21.46, euclid=27.32
#   - Frame 34, Pred ID=6, class=car, pos=(2.40, 0.18, 3.04), error_x=16.85, error_y=1.58, error_z=21.46, euclid=27.33
#   - Frame 35, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.85, error_y=1.58, error_z=21.47, euclid=27.34
#   - Frame 36, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.85, error_y=1.58, error_z=21.47, euclid=27.34
#   - Frame 37, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.85, error_y=1.58, error_z=21.47, euclid=27.34
#   - Frame 38, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.85, error_y=1.58, error_z=21.47, euclid=27.34
#   - Frame 39, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.85, error_y=1.58, error_z=21.47, euclid=27.34
#   - Frame 40, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.85, error_y=1.58, error_z=21.47, euclid=27.34
#   - Frame 41, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.85, error_y=1.58, error_z=21.47, euclid=27.34
#   - Frame 42, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.85, error_y=1.58, error_z=21.47, euclid=27.34
#   - Frame 43, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.84, error_y=1.57, error_z=21.47, euclid=27.34
#   - Frame 44, Pred ID=6, class=car, pos=(2.37, 0.18, 2.99), error_x=16.86, error_y=1.58, error_z=21.51, euclid=27.38
#   - Frame 45, Pred ID=6, class=car, pos=(2.37, 0.18, 2.99), error_x=16.86, error_y=1.58, error_z=21.51, euclid=27.38
#   - Frame 46, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.85, error_y=1.57, error_z=21.48, euclid=27.35
#   - Frame 47, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.85, error_y=1.57, error_z=21.48, euclid=27.35
#   - Frame 48, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.85, error_y=1.57, error_z=21.48, euclid=27.34
#   - Frame 49, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.84, error_y=1.57, error_z=21.47, euclid=27.33
#   - Frame 50, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.84, error_y=1.57, error_z=21.47, euclid=27.33
#   - Frame 51, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.84, error_y=1.57, error_z=21.47, euclid=27.33
#   - Frame 52, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.84, error_y=1.57, error_z=21.47, euclid=27.33
#   - Frame 53, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.83, error_y=1.57, error_z=21.47, euclid=27.33
#   - Frame 54, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.83, error_y=1.57, error_z=21.47, euclid=27.33
#   - Frame 55, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.83, error_y=1.57, error_z=21.46, euclid=27.31
#   - Frame 56, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.82, error_y=1.57, error_z=21.45, euclid=27.31
#   - Frame 57, Pred ID=6, class=car, pos=(2.42, 0.18, 3.05), error_x=16.82, error_y=1.57, error_z=21.44, euclid=27.29
#   - Frame 58, Pred ID=6, class=car, pos=(2.42, 0.18, 3.05), error_x=16.81, error_y=1.57, error_z=21.44, euclid=27.29
#   - Frame 59, Pred ID=6, class=car, pos=(2.40, 0.18, 3.04), error_x=16.83, error_y=1.57, error_z=21.45, euclid=27.31
#   - Frame 60, Pred ID=6, class=car, pos=(2.40, 0.18, 3.04), error_x=16.83, error_y=1.57, error_z=21.45, euclid=27.31
#   - Frame 61, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.82, error_y=1.57, error_z=21.45, euclid=27.31
#   - Frame 62, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.83, error_y=1.57, error_z=21.47, euclid=27.32
#   - Frame 63, Pred ID=6, class=car, pos=(2.40, 0.18, 3.04), error_x=16.82, error_y=1.57, error_z=21.45, euclid=27.31
#   - Frame 64, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.83, error_y=1.57, error_z=21.47, euclid=27.32
#   - Frame 65, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.83, error_y=1.57, error_z=21.46, euclid=27.32
#   - Frame 66, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.83, error_y=1.56, error_z=21.46, euclid=27.32
#   - Frame 67, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.83, error_y=1.56, error_z=21.46, euclid=27.32
#   - Frame 68, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=16.83, error_y=1.56, error_z=21.46, euclid=27.32
#   - Frame 69, Pred ID=6, class=car, pos=(2.40, 0.18, 3.05), error_x=16.83, error_y=1.56, error_z=21.44, euclid=27.30
#   - Frame 70, Pred ID=6, class=car, pos=(2.41, 0.18, 3.05), error_x=16.81, error_y=1.56, error_z=21.44, euclid=27.29
#   - Frame 71, Pred ID=6, class=car, pos=(2.40, 0.18, 3.04), error_x=16.82, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 72, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.82, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 73, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.82, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 74, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.82, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 75, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.82, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 76, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.82, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 77, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 78, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 79, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 80, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 81, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 82, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.56, error_z=21.45, euclid=27.30
#   - Frame 83, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.82, error_y=1.56, error_z=21.46, euclid=27.31
#   - Frame 84, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.56, error_z=21.45, euclid=27.29
#   - Frame 85, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.56, error_z=21.45, euclid=27.29
#   - Frame 86, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.56, error_z=21.45, euclid=27.29
#   - Frame 87, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.55, error_z=21.45, euclid=27.29
#   - Frame 88, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.55, error_z=21.45, euclid=27.29
#   - Frame 89, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.56, error_z=21.44, euclid=27.29
#   - Frame 90, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.81, error_y=1.56, error_z=21.44, euclid=27.29
#   - Frame 91, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.82, error_y=1.56, error_z=21.46, euclid=27.31
#   - Frame 92, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.81, error_y=1.56, error_z=21.46, euclid=27.30
#   - Frame 93, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.81, error_y=1.56, error_z=21.46, euclid=27.30
#   - Frame 94, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.81, error_y=1.56, error_z=21.46, euclid=27.30
#   - Frame 95, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.81, error_y=1.56, error_z=21.46, euclid=27.30
#   - Frame 96, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.81, error_y=1.56, error_z=21.46, euclid=27.30
#   - Frame 97, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.82, error_y=1.55, error_z=21.47, euclid=27.32
#   - Frame 98, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.82, error_y=1.55, error_z=21.47, euclid=27.32
#   - Frame 99, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.80, error_y=1.55, error_z=21.44, euclid=27.29
#   - Frame 100, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.80, error_y=1.55, error_z=21.44, euclid=27.28
#   - Frame 101, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.81, error_y=1.55, error_z=21.45, euclid=27.30
#   - Frame 102, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.81, error_y=1.55, error_z=21.45, euclid=27.30
#   - Frame 103, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.81, error_y=1.55, error_z=21.45, euclid=27.30
#   - Frame 104, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.81, error_y=1.55, error_z=21.45, euclid=27.30
#   - Frame 105, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.81, error_y=1.55, error_z=21.45, euclid=27.30
#   - Frame 106, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.80, error_y=1.55, error_z=21.44, euclid=27.28
#   - Frame 107, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.80, error_y=1.55, error_z=21.44, euclid=27.28
#   - Frame 108, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.79, error_y=1.55, error_z=21.44, euclid=27.28
#   - Frame 109, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.79, error_y=1.55, error_z=21.44, euclid=27.28
#   - Frame 110, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.79, error_y=1.55, error_z=21.44, euclid=27.28
#   - Frame 111, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.79, error_y=1.55, error_z=21.44, euclid=27.28
#   - Frame 112, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.79, error_y=1.55, error_z=21.44, euclid=27.28
#   - Frame 113, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.79, error_y=1.55, error_z=21.44, euclid=27.27
#   - Frame 114, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.79, error_y=1.55, error_z=21.44, euclid=27.27
#   - Frame 115, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.80, error_y=1.55, error_z=21.45, euclid=27.29
#   - Frame 116, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.80, error_y=1.55, error_z=21.45, euclid=27.29
#   - Frame 117, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.79, error_y=1.55, error_z=21.44, euclid=27.28
#   - Frame 118, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.79, error_y=1.55, error_z=21.44, euclid=27.27
#   - Frame 119, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.79, error_y=1.55, error_z=21.44, euclid=27.27
#   - Frame 120, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=16.82, error_y=1.54, error_z=21.44, euclid=27.29
#   - Frame 121, Pred ID=6, class=car, pos=(2.36, 0.18, 3.04), error_x=16.83, error_y=1.54, error_z=21.43, euclid=27.30
#   - Frame 122, Pred ID=6, class=car, pos=(2.36, 0.18, 3.04), error_x=16.83, error_y=1.54, error_z=21.43, euclid=27.30
#   - Frame 123, Pred ID=6, class=car, pos=(2.35, 0.18, 3.03), error_x=16.85, error_y=1.54, error_z=21.45, euclid=27.32
#   - Frame 124, Pred ID=6, class=car, pos=(2.35, 0.18, 3.03), error_x=16.85, error_y=1.54, error_z=21.45, euclid=27.32
#   - Frame 125, Pred ID=6, class=car, pos=(2.35, 0.18, 3.03), error_x=16.85, error_y=1.54, error_z=21.45, euclid=27.32
#   - Frame 126, Pred ID=6, class=car, pos=(2.34, 0.18, 3.03), error_x=16.85, error_y=1.54, error_z=21.45, euclid=27.32
#   - Frame 127, Pred ID=6, class=car, pos=(2.33, 0.18, 3.01), error_x=16.86, error_y=1.54, error_z=21.46, euclid=27.33
#   - Frame 128, Pred ID=6, class=car, pos=(2.26, 0.18, 2.96), error_x=16.94, error_y=1.54, error_z=21.51, euclid=27.42
#   - Frame 129, Pred ID=2, class=car, pos=(2.08, 0.17, 2.96), error_x=17.11, error_y=1.55, error_z=21.51, euclid=27.53
#   - Frame 130, Pred ID=2, class=car, pos=(2.08, 0.17, 2.96), error_x=17.11, error_y=1.55, error_z=21.51, euclid=27.53
#   - Frame 131, Pred ID=2, class=car, pos=(2.09, 0.17, 2.98), error_x=17.10, error_y=1.55, error_z=21.49, euclid=27.51
#   - Frame 132, Pred ID=6, class=car, pos=(2.34, 0.18, 3.00), error_x=16.85, error_y=1.53, error_z=21.47, euclid=27.34
#   - Frame 133, Pred ID=6, class=car, pos=(2.36, 0.18, 3.00), error_x=16.83, error_y=1.54, error_z=21.47, euclid=27.32
#   - Frame 134, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=16.84, error_y=1.54, error_z=21.46, euclid=27.32
#   - Frame 135, Pred ID=6, class=car, pos=(2.34, 0.18, 3.00), error_x=16.85, error_y=1.54, error_z=21.47, euclid=27.33
#   - Frame 136, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=16.84, error_y=1.53, error_z=21.46, euclid=27.32
#   - Frame 137, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=16.84, error_y=1.53, error_z=21.45, euclid=27.32
#   - Frame 138, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=16.84, error_y=1.53, error_z=21.45, euclid=27.32
#   - Frame 139, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=16.84, error_y=1.53, error_z=21.45, euclid=27.32
#   - Frame 140, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=16.84, error_y=1.53, error_z=21.45, euclid=27.32
#   - Frame 141, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=16.81, error_y=1.53, error_z=21.43, euclid=27.28
#   - Frame 142, Pred ID=6, class=car, pos=(2.37, 0.18, 3.00), error_x=16.81, error_y=1.53, error_z=21.47, euclid=27.31
#   - Frame 143, Pred ID=6, class=car, pos=(2.37, 0.18, 2.99), error_x=16.82, error_y=1.53, error_z=21.48, euclid=27.32
#   - Frame 144, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.80, error_y=1.53, error_z=21.45, euclid=27.29
#   - Frame 145, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.80, error_y=1.53, error_z=21.45, euclid=27.29
#   - Frame 146, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.79, error_y=1.53, error_z=21.45, euclid=27.29
#   - Frame 147, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=16.79, error_y=1.53, error_z=21.45, euclid=27.29
#   - Frame 148, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.79, error_y=1.53, error_z=21.44, euclid=27.27
#   - Frame 149, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.79, error_y=1.53, error_z=21.44, euclid=27.27
#   - Frame 150, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.78, error_y=1.53, error_z=21.44, euclid=27.27
#   - Frame 151, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.78, error_y=1.53, error_z=21.43, euclid=27.26
#   - Frame 152, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=16.78, error_y=1.53, error_z=21.44, euclid=27.27
#   - Frame 153, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.77, error_y=1.53, error_z=21.42, euclid=27.25
#   - Frame 154, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.77, error_y=1.53, error_z=21.42, euclid=27.25
#   - Frame 155, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.77, error_y=1.53, error_z=21.42, euclid=27.25
#   - Frame 156, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.77, error_y=1.53, error_z=21.42, euclid=27.25
#   - Frame 157, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.77, error_y=1.52, error_z=21.42, euclid=27.25
#   - Frame 158, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.77, error_y=1.52, error_z=21.42, euclid=27.25
#   - Frame 159, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=16.77, error_y=1.52, error_z=21.42, euclid=27.25
#   - Frame 160, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=16.80, error_y=1.52, error_z=21.42, euclid=27.26
#   - Frame 161, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=16.80, error_y=1.52, error_z=21.42, euclid=27.26
#   - Frame 162, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=16.80, error_y=1.52, error_z=21.42, euclid=27.26
#   - Frame 163, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=16.80, error_y=1.52, error_z=21.42, euclid=27.26
#   - Frame 164, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=16.80, error_y=1.52, error_z=21.42, euclid=27.26
#   - Frame 165, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=16.80, error_y=1.52, error_z=21.42, euclid=27.26
#   - Frame 166, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=16.80, error_y=1.52, error_z=21.42, euclid=27.26
#   - Frame 167, Pred ID=6, class=car, pos=(2.37, 0.18, 3.03), error_x=16.81, error_y=1.52, error_z=21.43, euclid=27.28
#   - Frame 168, Pred ID=6, class=car, pos=(2.37, 0.18, 3.03), error_x=16.81, error_y=1.52, error_z=21.43, euclid=27.28
#   - Frame 169, Pred ID=6, class=car, pos=(2.37, 0.18, 3.03), error_x=16.81, error_y=1.52, error_z=21.43, euclid=27.28
#   - Frame 170, Pred ID=6, class=car, pos=(2.37, 0.18, 3.03), error_x=16.81, error_y=1.52, error_z=21.43, euclid=27.28
#   - Frame 171, Pred ID=6, class=car, pos=(2.36, 0.18, 3.03), error_x=16.81, error_y=1.52, error_z=21.43, euclid=27.28
#   - Frame 172, Pred ID=6, class=car, pos=(2.36, 0.18, 3.03), error_x=16.81, error_y=1.52, error_z=21.43, euclid=27.28
#   - Frame 173, Pred ID=6, class=car, pos=(2.36, 0.18, 3.03), error_x=16.81, error_y=1.52, error_z=21.43, euclid=27.28
#   - Frame 174, Pred ID=6, class=car, pos=(2.35, 0.18, 2.99), error_x=16.82, error_y=1.52, error_z=21.47, euclid=27.31
#   - Frame 175, Pred ID=6, class=car, pos=(2.35, 0.18, 2.98), error_x=16.82, error_y=1.52, error_z=21.48, euclid=27.32
#   - Frame 176, Pred ID=6, class=car, pos=(2.35, 0.18, 2.98), error_x=16.82, error_y=1.52, error_z=21.48, euclid=27.32
#   - Frame 177, Pred ID=6, class=car, pos=(2.35, 0.18, 2.98), error_x=16.82, error_y=1.51, error_z=21.48, euclid=27.32
#   - Frame 178, Pred ID=6, class=car, pos=(2.35, 0.18, 2.98), error_x=16.82, error_y=1.51, error_z=21.48, euclid=27.32
#   - Frame 179, Pred ID=6, class=car, pos=(2.35, 0.18, 2.98), error_x=16.82, error_y=1.51, error_z=21.48, euclid=27.32
#   - Frame 180, Pred ID=6, class=car, pos=(2.35, 0.18, 2.96), error_x=16.82, error_y=1.51, error_z=21.49, euclid=27.33
#   - Frame 181, Pred ID=94, class=car, pos=(2.17, 0.18, 2.95), error_x=17.00, error_y=1.52, error_z=21.50, euclid=27.45
#   - Frame 182, Pred ID=94, class=car, pos=(2.19, 0.18, 2.93), error_x=16.98, error_y=1.52, error_z=21.53, euclid=27.46
#   - Frame 183, Pred ID=94, class=car, pos=(2.24, 0.18, 2.95), error_x=16.92, error_y=1.51, error_z=21.51, euclid=27.41
#   - Frame 184, Pred ID=94, class=car, pos=(2.29, 0.18, 2.96), error_x=16.87, error_y=1.51, error_z=21.49, euclid=27.36
#   - Frame 185, Pred ID=94, class=car, pos=(2.33, 0.18, 2.95), error_x=16.84, error_y=1.51, error_z=21.50, euclid=27.35
#   - Frame 186, Pred ID=94, class=car, pos=(2.32, 0.18, 2.92), error_x=16.84, error_y=1.51, error_z=21.54, euclid=27.38
#   - Frame 187, Pred ID=94, class=car, pos=(2.33, 0.18, 2.91), error_x=16.83, error_y=1.51, error_z=21.55, euclid=27.39
#   - Frame 188, Pred ID=94, class=car, pos=(2.31, 0.18, 2.87), error_x=16.85, error_y=1.52, error_z=21.58, euclid=27.42
#   - Frame 189, Pred ID=8, class=car, pos=(1.72, 0.17, 2.99), error_x=17.44, error_y=1.53, error_z=21.46, euclid=27.70
#   - Frame 190, Pred ID=8, class=car, pos=(1.73, 0.17, 2.99), error_x=17.44, error_y=1.52, error_z=21.46, euclid=27.69
#   - Frame 191, Pred ID=8, class=car, pos=(1.73, 0.17, 3.00), error_x=17.43, error_y=1.52, error_z=21.45, euclid=27.68
#   - Frame 192, Pred ID=8, class=car, pos=(1.73, 0.17, 3.00), error_x=17.43, error_y=1.52, error_z=21.45, euclid=27.68
#   - Frame 193, Pred ID=99, class=car, pos=(2.10, 0.17, 2.98), error_x=17.06, error_y=1.52, error_z=21.47, euclid=27.47
#   - Frame 194, Pred ID=99, class=car, pos=(2.10, 0.17, 2.98), error_x=17.06, error_y=1.52, error_z=21.47, euclid=27.47
#   - Frame 195, Pred ID=100, class=car, pos=(2.40, 0.18, 3.05), error_x=16.76, error_y=1.51, error_z=21.40, euclid=27.22
#   - Frame 196, Pred ID=101, class=car, pos=(2.37, 0.18, 2.99), error_x=16.78, error_y=1.51, error_z=21.46, euclid=27.29
#   - Frame 197, Pred ID=101, class=car, pos=(2.34, 0.18, 2.92), error_x=16.82, error_y=1.51, error_z=21.53, euclid=27.37
#   - Frame 198, Pred ID=101, class=car, pos=(2.34, 0.18, 2.92), error_x=16.82, error_y=1.51, error_z=21.53, euclid=27.37
#   - Frame 199, Pred ID=101, class=car, pos=(2.34, 0.18, 2.92), error_x=16.82, error_y=1.51, error_z=21.53, euclid=27.37
#   - Frame 200, Pred ID=101, class=car, pos=(2.34, 0.18, 2.92), error_x=16.82, error_y=1.51, error_z=21.53, euclid=27.36
#   - Frame 201, Pred ID=101, class=car, pos=(2.34, 0.18, 2.92), error_x=16.82, error_y=1.51, error_z=21.53, euclid=27.36
#   - Frame 202, Pred ID=101, class=car, pos=(2.34, 0.18, 2.92), error_x=16.82, error_y=1.51, error_z=21.53, euclid=27.36
#   - Frame 203, Pred ID=101, class=car, pos=(2.34, 0.18, 2.92), error_x=16.81, error_y=1.51, error_z=21.53, euclid=27.36
#   - Frame 204, Pred ID=101, class=car, pos=(2.34, 0.18, 2.92), error_x=16.81, error_y=1.51, error_z=21.53, euclid=27.36
#   - Frame 205, Pred ID=101, class=car, pos=(2.34, 0.18, 2.92), error_x=16.81, error_y=1.51, error_z=21.53, euclid=27.36
#   - Frame 206, Pred ID=101, class=car, pos=(2.34, 0.17, 2.91), error_x=16.82, error_y=1.51, error_z=21.54, euclid=27.37
#   - Frame 207, Pred ID=101, class=car, pos=(2.33, 0.17, 2.91), error_x=16.82, error_y=1.51, error_z=21.54, euclid=27.37
#   - Frame 208, Pred ID=101, class=car, pos=(2.31, 0.17, 2.86), error_x=16.84, error_y=1.51, error_z=21.59, euclid=27.42
#   => MAE for GT ID=0: x=16.85, y=1.55, z=21.47 | mean_euclid=27.33
#
# GT car (ID=1) at (16.29, 1.60, 23.74) over all frames has 209 matched predictions:
#   - Frame 0, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 1, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 2, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 3, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 4, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 5, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 6, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 7, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 8, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 9, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 10, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 11, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 12, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 13, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 14, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 15, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 16, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 17, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 18, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.74, euclid=25.02
#   - Frame 19, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 20, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 21, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.91, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 22, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.91, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 23, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.91, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 24, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.75, euclid=25.02
#   - Frame 25, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.75, euclid=25.02
#   - Frame 26, Pred ID=6, class=car, pos=(2.38, 0.18, 3.00), error_x=13.91, error_y=1.42, error_z=20.75, euclid=25.02
#   - Frame 27, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.91, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 28, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.91, error_y=1.42, error_z=20.73, euclid=25.01
#   - Frame 29, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 30, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.97
#   - Frame 31, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.97
#   - Frame 32, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 33, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.97
#   - Frame 34, Pred ID=6, class=car, pos=(2.40, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 35, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 36, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 37, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 38, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 39, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 40, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 41, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 42, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 43, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 44, Pred ID=6, class=car, pos=(2.37, 0.18, 2.99), error_x=13.92, error_y=1.43, error_z=20.76, euclid=25.03
#   - Frame 45, Pred ID=6, class=car, pos=(2.37, 0.18, 2.99), error_x=13.92, error_y=1.43, error_z=20.76, euclid=25.03
#   - Frame 46, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.74, euclid=25.00
#   - Frame 47, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.74, euclid=25.01
#   - Frame 48, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.90, error_y=1.42, error_z=20.74, euclid=25.01
#   - Frame 49, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.89, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 50, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.89, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 51, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.89, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 52, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.89, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 53, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.89, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 54, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.89, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 55, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 56, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.88, error_y=1.43, error_z=20.71, euclid=24.98
#   - Frame 57, Pred ID=6, class=car, pos=(2.42, 0.18, 3.05), error_x=13.88, error_y=1.43, error_z=20.70, euclid=24.96
#   - Frame 58, Pred ID=6, class=car, pos=(2.42, 0.18, 3.05), error_x=13.88, error_y=1.43, error_z=20.70, euclid=24.96
#   - Frame 59, Pred ID=6, class=car, pos=(2.40, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.71, euclid=24.98
#   - Frame 60, Pred ID=6, class=car, pos=(2.40, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.71, euclid=24.98
#   - Frame 61, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.71, euclid=24.98
#   - Frame 62, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.72, euclid=24.99
#   - Frame 63, Pred ID=6, class=car, pos=(2.40, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.71, euclid=24.98
#   - Frame 64, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.72, euclid=24.99
#   - Frame 65, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.73, euclid=24.99
#   - Frame 66, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 67, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 68, Pred ID=6, class=car, pos=(2.39, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.73, euclid=25.00
#   - Frame 69, Pred ID=6, class=car, pos=(2.40, 0.18, 3.05), error_x=13.89, error_y=1.42, error_z=20.70, euclid=24.97
#   - Frame 70, Pred ID=6, class=car, pos=(2.41, 0.18, 3.05), error_x=13.88, error_y=1.42, error_z=20.70, euclid=24.97
#   - Frame 71, Pred ID=6, class=car, pos=(2.40, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 72, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 73, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 74, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 75, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 76, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 77, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 78, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 79, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 80, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 81, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 82, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 83, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.42, error_z=20.73, euclid=24.99
#   - Frame 84, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 85, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 86, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 87, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.71, euclid=24.98
#   - Frame 88, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.72, euclid=24.98
#   - Frame 89, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 90, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 91, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 92, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 93, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 94, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 95, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 96, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 97, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.91, error_y=1.43, error_z=20.74, euclid=25.01
#   - Frame 98, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.91, error_y=1.43, error_z=20.74, euclid=25.01
#   - Frame 99, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.72, euclid=24.98
#   - Frame 100, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.72, euclid=24.98
#   - Frame 101, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 102, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 103, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 104, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 105, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 106, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.42, error_z=20.72, euclid=24.98
#   - Frame 107, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 108, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 109, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 110, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 111, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 112, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 113, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 114, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 115, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 116, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 117, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 118, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 119, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.98
#   - Frame 120, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=13.92, error_y=1.43, error_z=20.72, euclid=25.00
#   - Frame 121, Pred ID=6, class=car, pos=(2.36, 0.18, 3.04), error_x=13.93, error_y=1.43, error_z=20.72, euclid=25.01
#   - Frame 122, Pred ID=6, class=car, pos=(2.36, 0.18, 3.04), error_x=13.93, error_y=1.43, error_z=20.72, euclid=25.01
#   - Frame 123, Pred ID=6, class=car, pos=(2.35, 0.18, 3.03), error_x=13.95, error_y=1.43, error_z=20.73, euclid=25.03
#   - Frame 124, Pred ID=6, class=car, pos=(2.35, 0.18, 3.03), error_x=13.95, error_y=1.43, error_z=20.73, euclid=25.03
#   - Frame 125, Pred ID=6, class=car, pos=(2.35, 0.18, 3.03), error_x=13.95, error_y=1.43, error_z=20.73, euclid=25.03
#   - Frame 126, Pred ID=6, class=car, pos=(2.34, 0.18, 3.03), error_x=13.95, error_y=1.43, error_z=20.73, euclid=25.03
#   - Frame 127, Pred ID=6, class=car, pos=(2.33, 0.18, 3.01), error_x=13.96, error_y=1.43, error_z=20.74, euclid=25.05
#   - Frame 128, Pred ID=6, class=car, pos=(2.26, 0.18, 2.96), error_x=14.04, error_y=1.43, error_z=20.79, euclid=25.13
#   - Frame 129, Pred ID=2, class=car, pos=(2.08, 0.17, 2.96), error_x=14.21, error_y=1.44, error_z=20.79, euclid=25.23
#   - Frame 130, Pred ID=2, class=car, pos=(2.08, 0.17, 2.96), error_x=14.21, error_y=1.44, error_z=20.79, euclid=25.23
#   - Frame 131, Pred ID=2, class=car, pos=(2.09, 0.17, 2.98), error_x=14.20, error_y=1.44, error_z=20.78, euclid=25.21
#   - Frame 132, Pred ID=6, class=car, pos=(2.34, 0.18, 3.00), error_x=13.96, error_y=1.42, error_z=20.76, euclid=25.05
#   - Frame 133, Pred ID=6, class=car, pos=(2.36, 0.18, 3.00), error_x=13.94, error_y=1.43, error_z=20.76, euclid=25.04
#   - Frame 134, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=13.95, error_y=1.43, error_z=20.75, euclid=25.04
#   - Frame 135, Pred ID=6, class=car, pos=(2.34, 0.18, 3.00), error_x=13.95, error_y=1.43, error_z=20.76, euclid=25.05
#   - Frame 136, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=13.95, error_y=1.43, error_z=20.75, euclid=25.04
#   - Frame 137, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=13.95, error_y=1.43, error_z=20.75, euclid=25.04
#   - Frame 138, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=13.95, error_y=1.43, error_z=20.75, euclid=25.04
#   - Frame 139, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=13.95, error_y=1.43, error_z=20.75, euclid=25.04
#   - Frame 140, Pred ID=6, class=car, pos=(2.35, 0.18, 3.01), error_x=13.95, error_y=1.43, error_z=20.75, euclid=25.04
#   - Frame 141, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=13.91, error_y=1.43, error_z=20.72, euclid=25.00
#   - Frame 142, Pred ID=6, class=car, pos=(2.37, 0.18, 3.00), error_x=13.92, error_y=1.43, error_z=20.76, euclid=25.04
#   - Frame 143, Pred ID=6, class=car, pos=(2.37, 0.18, 2.99), error_x=13.93, error_y=1.43, error_z=20.77, euclid=25.05
#   - Frame 144, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.91, error_y=1.43, error_z=20.75, euclid=25.02
#   - Frame 145, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.91, error_y=1.43, error_z=20.75, euclid=25.02
#   - Frame 146, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.91, error_y=1.43, error_z=20.75, euclid=25.02
#   - Frame 147, Pred ID=6, class=car, pos=(2.39, 0.18, 3.01), error_x=13.91, error_y=1.43, error_z=20.75, euclid=25.02
#   - Frame 148, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 149, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 150, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 151, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.99
#   - Frame 152, Pred ID=6, class=car, pos=(2.40, 0.18, 3.03), error_x=13.90, error_y=1.43, error_z=20.73, euclid=25.00
#   - Frame 153, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.99
#   - Frame 154, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.99
#   - Frame 155, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.99
#   - Frame 156, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.99
#   - Frame 157, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.99
#   - Frame 158, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.99
#   - Frame 159, Pred ID=6, class=car, pos=(2.41, 0.18, 3.04), error_x=13.89, error_y=1.43, error_z=20.72, euclid=24.99
#   - Frame 160, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=13.92, error_y=1.43, error_z=20.72, euclid=25.00
#   - Frame 161, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=13.92, error_y=1.43, error_z=20.72, euclid=25.00
#   - Frame 162, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=13.92, error_y=1.43, error_z=20.72, euclid=25.00
#   - Frame 163, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=13.92, error_y=1.43, error_z=20.72, euclid=25.00
#   - Frame 164, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=13.92, error_y=1.43, error_z=20.72, euclid=25.00
#   - Frame 165, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=13.92, error_y=1.43, error_z=20.72, euclid=25.00
#   - Frame 166, Pred ID=6, class=car, pos=(2.38, 0.18, 3.04), error_x=13.92, error_y=1.43, error_z=20.72, euclid=25.01
#   - Frame 167, Pred ID=6, class=car, pos=(2.37, 0.18, 3.03), error_x=13.93, error_y=1.43, error_z=20.74, euclid=25.02
#   - Frame 168, Pred ID=6, class=car, pos=(2.37, 0.18, 3.03), error_x=13.93, error_y=1.43, error_z=20.74, euclid=25.02
#   - Frame 169, Pred ID=6, class=car, pos=(2.37, 0.18, 3.03), error_x=13.93, error_y=1.43, error_z=20.74, euclid=25.02
#   - Frame 170, Pred ID=6, class=car, pos=(2.37, 0.18, 3.03), error_x=13.93, error_y=1.43, error_z=20.74, euclid=25.02
#   - Frame 171, Pred ID=6, class=car, pos=(2.36, 0.18, 3.03), error_x=13.93, error_y=1.43, error_z=20.74, euclid=25.02
#   - Frame 172, Pred ID=6, class=car, pos=(2.36, 0.18, 3.03), error_x=13.94, error_y=1.43, error_z=20.74, euclid=25.03
#   - Frame 173, Pred ID=6, class=car, pos=(2.36, 0.18, 3.03), error_x=13.94, error_y=1.43, error_z=20.74, euclid=25.03
#   - Frame 174, Pred ID=6, class=car, pos=(2.35, 0.18, 2.99), error_x=13.95, error_y=1.43, error_z=20.77, euclid=25.06
#   - Frame 175, Pred ID=6, class=car, pos=(2.35, 0.18, 2.98), error_x=13.95, error_y=1.43, error_z=20.79, euclid=25.07
#   - Frame 176, Pred ID=6, class=car, pos=(2.35, 0.18, 2.98), error_x=13.95, error_y=1.43, error_z=20.79, euclid=25.07
#   - Frame 177, Pred ID=6, class=car, pos=(2.35, 0.18, 2.98), error_x=13.95, error_y=1.43, error_z=20.79, euclid=25.07
#   - Frame 178, Pred ID=6, class=car, pos=(2.35, 0.18, 2.98), error_x=13.95, error_y=1.43, error_z=20.79, euclid=25.07
#   - Frame 179, Pred ID=6, class=car, pos=(2.35, 0.18, 2.98), error_x=13.95, error_y=1.43, error_z=20.79, euclid=25.07
#   - Frame 180, Pred ID=6, class=car, pos=(2.35, 0.18, 2.96), error_x=13.95, error_y=1.43, error_z=20.80, euclid=25.09
#   - Frame 181, Pred ID=94, class=car, pos=(2.17, 0.18, 2.95), error_x=14.13, error_y=1.43, error_z=20.81, euclid=25.20
#   - Frame 182, Pred ID=94, class=car, pos=(2.19, 0.18, 2.93), error_x=14.11, error_y=1.43, error_z=20.84, euclid=25.20
#   - Frame 183, Pred ID=94, class=car, pos=(2.24, 0.18, 2.95), error_x=14.06, error_y=1.43, error_z=20.82, euclid=25.16
#   - Frame 184, Pred ID=94, class=car, pos=(2.29, 0.18, 2.96), error_x=14.01, error_y=1.43, error_z=20.80, euclid=25.12
#   - Frame 185, Pred ID=94, class=car, pos=(2.33, 0.18, 2.95), error_x=13.97, error_y=1.43, error_z=20.81, euclid=25.11
#   - Frame 186, Pred ID=94, class=car, pos=(2.32, 0.18, 2.92), error_x=13.97, error_y=1.43, error_z=20.85, euclid=25.14
#   - Frame 187, Pred ID=94, class=car, pos=(2.33, 0.18, 2.91), error_x=13.97, error_y=1.43, error_z=20.86, euclid=25.15
#   - Frame 188, Pred ID=98, class=car, pos=(2.21, 0.17, 2.94), error_x=14.09, error_y=1.44, error_z=20.82, euclid=25.18
#   - Frame 189, Pred ID=8, class=car, pos=(1.72, 0.17, 2.99), error_x=14.58, error_y=1.44, error_z=20.78, euclid=25.42
#   - Frame 190, Pred ID=8, class=car, pos=(1.73, 0.17, 2.99), error_x=14.57, error_y=1.44, error_z=20.77, euclid=25.41
#   - Frame 191, Pred ID=8, class=car, pos=(1.73, 0.17, 3.00), error_x=14.57, error_y=1.44, error_z=20.76, euclid=25.41
#   - Frame 192, Pred ID=8, class=car, pos=(1.73, 0.17, 3.00), error_x=14.57, error_y=1.44, error_z=20.76, euclid=25.41
#   - Frame 193, Pred ID=99, class=car, pos=(2.10, 0.17, 2.98), error_x=14.20, error_y=1.44, error_z=20.79, euclid=25.22
#   - Frame 194, Pred ID=99, class=car, pos=(2.10, 0.17, 2.98), error_x=14.20, error_y=1.44, error_z=20.79, euclid=25.21
#   - Frame 195, Pred ID=100, class=car, pos=(2.40, 0.18, 3.05), error_x=13.90, error_y=1.43, error_z=20.71, euclid=24.99
#   - Frame 196, Pred ID=101, class=car, pos=(2.37, 0.18, 2.99), error_x=13.92, error_y=1.43, error_z=20.78, euclid=25.05
# ...
#   - Frame 204, GT ID=16, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 204, GT ID=16, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.15, 0.33, 0.78)
#   - Frame 204, GT ID=16, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 204, GT ID=16, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.18, 2.92)
#   - Frame 204, GT ID=18, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 204, GT ID=18, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.15, 0.33, 0.78)
#   - Frame 204, GT ID=18, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 204, GT ID=18, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.18, 2.92)
#   - Frame 205, GT ID=0, GT class=car => Pred ID=44, Pred class=pedestrian, pos=(-1.41, 0.13, 1.84)
#   - Frame 205, GT ID=0, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.17, 0.34, 0.77)
#   - Frame 205, GT ID=0, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.71, 0.26, 1.77)
#   - Frame 205, GT ID=1, GT class=car => Pred ID=44, Pred class=pedestrian, pos=(-1.41, 0.13, 1.84)
#   - Frame 205, GT ID=1, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.17, 0.34, 0.77)
#   - Frame 205, GT ID=1, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.71, 0.26, 1.77)
#   - Frame 205, GT ID=2, GT class=car => Pred ID=44, Pred class=pedestrian, pos=(-1.41, 0.13, 1.84)
#   - Frame 205, GT ID=2, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.17, 0.34, 0.77)
#   - Frame 205, GT ID=2, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.71, 0.26, 1.77)
#   - Frame 205, GT ID=3, GT class=car => Pred ID=44, Pred class=pedestrian, pos=(-1.41, 0.13, 1.84)
#   - Frame 205, GT ID=3, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.17, 0.34, 0.77)
#   - Frame 205, GT ID=3, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.71, 0.26, 1.77)
#   - Frame 205, GT ID=11, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 205, GT ID=11, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.17, 0.34, 0.77)
#   - Frame 205, GT ID=11, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 205, GT ID=11, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.18, 2.92)
#   - Frame 205, GT ID=12, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 205, GT ID=12, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.17, 0.34, 0.77)
#   - Frame 205, GT ID=12, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 205, GT ID=12, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.18, 2.92)
#   - Frame 205, GT ID=15, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 205, GT ID=15, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.17, 0.34, 0.77)
#   - Frame 205, GT ID=15, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 205, GT ID=15, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.18, 2.92)
#   - Frame 205, GT ID=16, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 205, GT ID=16, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.17, 0.34, 0.77)
#   - Frame 205, GT ID=16, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 205, GT ID=16, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.18, 2.92)
#   - Frame 205, GT ID=17, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 205, GT ID=17, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.17, 0.34, 0.77)
#   - Frame 205, GT ID=17, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 205, GT ID=17, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.18, 2.92)
#   - Frame 205, GT ID=18, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 205, GT ID=18, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.17, 0.34, 0.77)
#   - Frame 205, GT ID=18, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 205, GT ID=18, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.18, 2.92)
#   - Frame 206, GT ID=0, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.19, 0.34, 0.77)
#   - Frame 206, GT ID=0, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.52, 0.24, 1.54)
#   - Frame 206, GT ID=0, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.43, 0.15, 1.84)
#   - Frame 206, GT ID=1, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.19, 0.34, 0.77)
#   - Frame 206, GT ID=1, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.52, 0.24, 1.54)
#   - Frame 206, GT ID=1, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.43, 0.15, 1.84)
#   - Frame 206, GT ID=2, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.19, 0.34, 0.77)
#   - Frame 206, GT ID=2, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.52, 0.24, 1.54)
#   - Frame 206, GT ID=2, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.43, 0.15, 1.84)
#   - Frame 206, GT ID=3, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.19, 0.34, 0.77)
#   - Frame 206, GT ID=3, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.52, 0.24, 1.54)
#   - Frame 206, GT ID=3, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.43, 0.15, 1.84)
#   - Frame 206, GT ID=11, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 206, GT ID=11, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.19, 0.34, 0.77)
#   - Frame 206, GT ID=11, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 206, GT ID=11, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.17, 2.91)
#   - Frame 206, GT ID=12, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 206, GT ID=12, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.19, 0.34, 0.77)
#   - Frame 206, GT ID=12, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 206, GT ID=12, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.17, 2.91)
#   - Frame 206, GT ID=15, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 206, GT ID=15, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.19, 0.34, 0.77)
#   - Frame 206, GT ID=15, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 206, GT ID=15, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.17, 2.91)
#   - Frame 206, GT ID=16, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 206, GT ID=16, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.19, 0.34, 0.77)
#   - Frame 206, GT ID=16, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 206, GT ID=16, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.17, 2.91)
#   - Frame 206, GT ID=17, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 206, GT ID=17, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.19, 0.34, 0.77)
#   - Frame 206, GT ID=17, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 206, GT ID=17, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.17, 2.91)
#   - Frame 206, GT ID=18, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 206, GT ID=18, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.19, 0.34, 0.77)
#   - Frame 206, GT ID=18, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.13, 0.17, 2.98)
#   - Frame 206, GT ID=18, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.34, 0.17, 2.91)
#   - Frame 207, GT ID=0, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.76)
#   - Frame 207, GT ID=0, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.42, 0.23, 1.40)
#   - Frame 207, GT ID=0, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.43, 0.15, 1.85)
#   - Frame 207, GT ID=0, GT class=car => Pred ID=106, Pred class=pedestrian, pos=(0.79, 0.19, 0.96)
#   - Frame 207, GT ID=1, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.76)
#   - Frame 207, GT ID=1, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.42, 0.23, 1.40)
#   - Frame 207, GT ID=1, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.43, 0.15, 1.85)
#   - Frame 207, GT ID=1, GT class=car => Pred ID=106, Pred class=pedestrian, pos=(0.79, 0.19, 0.96)
#   - Frame 207, GT ID=2, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.76)
#   - Frame 207, GT ID=2, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.42, 0.23, 1.40)
#   - Frame 207, GT ID=2, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.43, 0.15, 1.85)
#   - Frame 207, GT ID=2, GT class=car => Pred ID=106, Pred class=pedestrian, pos=(0.79, 0.19, 0.96)
#   - Frame 207, GT ID=3, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.76)
#   - Frame 207, GT ID=3, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.42, 0.23, 1.40)
#   - Frame 207, GT ID=3, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.43, 0.15, 1.85)
#   - Frame 207, GT ID=3, GT class=car => Pred ID=106, Pred class=pedestrian, pos=(0.79, 0.19, 0.96)
#   - Frame 207, GT ID=11, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 207, GT ID=11, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.76)
#   - Frame 207, GT ID=11, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 207, GT ID=11, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.33, 0.17, 2.91)
#   - Frame 207, GT ID=12, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 207, GT ID=12, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.76)
#   - Frame 207, GT ID=12, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 207, GT ID=12, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.33, 0.17, 2.91)
#   - Frame 207, GT ID=15, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 207, GT ID=15, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.76)
#   - Frame 207, GT ID=15, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 207, GT ID=15, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.33, 0.17, 2.91)
#   - Frame 207, GT ID=16, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 207, GT ID=16, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.76)
#   - Frame 207, GT ID=16, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 207, GT ID=16, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.33, 0.17, 2.91)
#   - Frame 207, GT ID=17, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 207, GT ID=17, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.76)
#   - Frame 207, GT ID=17, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 207, GT ID=17, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.33, 0.17, 2.91)
#   - Frame 207, GT ID=18, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 207, GT ID=18, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.76)
#   - Frame 207, GT ID=18, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 207, GT ID=18, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.33, 0.17, 2.91)
#   - Frame 208, GT ID=0, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.75)
#   - Frame 208, GT ID=0, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.36, 0.23, 1.31)
#   - Frame 208, GT ID=0, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.42, 0.15, 1.86)
#   - Frame 208, GT ID=0, GT class=car => Pred ID=106, Pred class=pedestrian, pos=(0.79, 0.19, 0.97)
#   - Frame 208, GT ID=1, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.75)
#   - Frame 208, GT ID=1, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.36, 0.23, 1.31)
#   - Frame 208, GT ID=1, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.42, 0.15, 1.86)
#   - Frame 208, GT ID=1, GT class=car => Pred ID=106, Pred class=pedestrian, pos=(0.79, 0.19, 0.97)
#   - Frame 208, GT ID=2, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.75)
#   - Frame 208, GT ID=2, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.36, 0.23, 1.31)
#   - Frame 208, GT ID=2, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.42, 0.15, 1.86)
#   - Frame 208, GT ID=2, GT class=car => Pred ID=106, Pred class=pedestrian, pos=(0.79, 0.19, 0.97)
#   - Frame 208, GT ID=3, GT class=car => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.75)
#   - Frame 208, GT ID=3, GT class=car => Pred ID=102, Pred class=pedestrian, pos=(-1.36, 0.23, 1.31)
#   - Frame 208, GT ID=3, GT class=car => Pred ID=104, Pred class=pedestrian, pos=(-1.42, 0.15, 1.86)
#   - Frame 208, GT ID=3, GT class=car => Pred ID=106, Pred class=pedestrian, pos=(0.79, 0.19, 0.97)
#   - Frame 208, GT ID=11, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 208, GT ID=11, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.75)
#   - Frame 208, GT ID=11, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 208, GT ID=11, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.31, 0.17, 2.86)
#   - Frame 208, GT ID=12, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 208, GT ID=12, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.75)
#   - Frame 208, GT ID=12, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 208, GT ID=12, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.31, 0.17, 2.86)
#   - Frame 208, GT ID=15, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 208, GT ID=15, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.75)
#   - Frame 208, GT ID=15, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 208, GT ID=15, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.31, 0.17, 2.86)
#   - Frame 208, GT ID=16, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 208, GT ID=16, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.75)
#   - Frame 208, GT ID=16, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 208, GT ID=16, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.31, 0.17, 2.86)
#   - Frame 208, GT ID=17, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 208, GT ID=17, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.75)
#   - Frame 208, GT ID=17, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 208, GT ID=17, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.31, 0.17, 2.86)
#   - Frame 208, GT ID=18, GT class=pedestrian => Pred ID=8, Pred class=car, pos=(1.73, 0.17, 3.00)
#   - Frame 208, GT ID=18, GT class=pedestrian => Pred ID=89, Pred class=cyclist, pos=(-1.20, 0.34, 0.75)
#   - Frame 208, GT ID=18, GT class=pedestrian => Pred ID=99, Pred class=car, pos=(2.12, 0.17, 2.98)
#   - Frame 208, GT ID=18, GT class=pedestrian => Pred ID=101, Pred class=car, pos=(2.31, 0.17, 2.86)
